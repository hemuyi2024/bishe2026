# %% [markdown]
# # HNSW + 在线 HMM 检索与 Recall@25 评估
#
# 使用真实 NetVLAD 数据：多轨迹 Query，每条轨迹按帧做 HNSW Top-K 检索后经 OnlineHMM 时序平滑；
# GT 采用坐标法（uav_infos.csv 经纬度 + 方圆 25 张），评估 Recall@25，对比「仅 HNSW」与「HNSW+HMM」。
# 当前帧预测位置采用真值。候选集为hnsw检索的20个∪上一帧的九宫格

# %%
import importlib
from pathlib import Path
import sys

_root = Path().resolve()
if _root.name == "hnsw_performance_analysis":
    _root = _root.parent
sys.path.insert(0, str(_root))

import numpy as np
import faiss

FPS = 4.0
FRAME_INTERVAL = 1.0 / FPS
EVAL_TOPK = 20
SAVE_TOPK = 10
WINDOW_SIZE = 3
EXPANSION_RADIUS_SCALE = 1.8
EXPANSION_RADIUS_FALLBACK_PX = 24.0
MAX_EXPANSION_CANDIDATES = 40
MAX_STATE_CANDIDATES = 40
USE_HMM_TOP1_FUSION = False
FUSION_HNSW_TOPN = 5

# 新增：基于预测位置的软惩罚（不剔除候选，只重排）
ENABLE_SOFT_SPATIAL_PENALTY = True
SOFT_PENALTY_REF_PX = 250.0   # 距离归一化参考尺度（像素）
SOFT_PENALTY_WEIGHT = 0.006 # 惩罚强度，越大越偏向近处

from demo_readH5 import (
    load_netvlad_descriptors,
    load_multi_netvlad_descriptors,
    DB_H5_PATHS,
    QUERY_H5_PATHS,
)
from scene_config import (
    get_db_scene_ranges,
    get_query_trajectory_ranges,
    get_scene_paths,
    DATASETS_BASE,
)
import coords_gt_utils
importlib.reload(coords_gt_utils)
from coords_gt_utils import (
    build_database_coords,
    build_gt_9_for_all_trajectories,
    get_geotransform_and_srs,
    lonlat_to_pixel,
    load_uav_infos,
)
from HMM.HMM import (
    OnlineHMM,
    WindowViterbiHMM,
    DEFAULT_ALPHA_SIGMA,
    DEFAULT_EMISSION_SCALE,
    DEFAULT_WINDOW_SIZE,
)

WINDOW_SIZE = max(WINDOW_SIZE, DEFAULT_WINDOW_SIZE)
print(
    f"HMM 参数: alpha_sigma={DEFAULT_ALPHA_SIGMA}, emission_scale={DEFAULT_EMISSION_SCALE}, "
    f"window_size={WINDOW_SIZE}, expansion_radius_scale={EXPANSION_RADIUS_SCALE}, "
    f"expansion_radius_fallback_px={EXPANSION_RADIUS_FALLBACK_PX}, max_state_candidates={MAX_STATE_CANDIDATES}, "
    f"use_top1_fusion={USE_HMM_TOP1_FUSION}, fusion_hnsw_topn={FUSION_HNSW_TOPN}"
)


def expand_candidates_with_radius(
    base_indices,
    base_distances,
    query_desc,
    db_descs,
    coords,
    db_start,
    db_end,
    anchor_idx=None,
    displacement=None,
    expansion_radius_px=None,
    max_expansion_candidates=MAX_EXPANSION_CANDIDATES,
    max_candidates=MAX_STATE_CANDIDATES,
):
    base_indices = np.asarray(base_indices, dtype=np.int64)
    base_distances = np.asarray(base_distances, dtype=np.float64)
    if base_indices.size == 0:
        return base_indices, base_distances, 0

    merged_pairs = [(int(idx), float(dist)) for idx, dist in zip(base_indices, base_distances)]
    if coords is None or anchor_idx is None or not (db_start <= int(anchor_idx) < db_end):
        return base_indices[:max_candidates], base_distances[:max_candidates], 0

    if expansion_radius_px is None or not np.isfinite(expansion_radius_px) or expansion_radius_px <= 0:
        expansion_radius_px = EXPANSION_RADIUS_FALLBACK_PX

    anchor_coord = coords[int(anchor_idx)]
    if np.any(np.isnan(anchor_coord)):
        return base_indices[:max_candidates], base_distances[:max_candidates], 0

    center = np.array(anchor_coord, dtype=np.float64)
    if displacement is not None:
        center = center + np.asarray(displacement, dtype=np.float64)

    scene_coords = coords[db_start:db_end]
    valid_mask = ~np.any(np.isnan(scene_coords), axis=1)
    if not np.any(valid_mask):
        return base_indices[:max_candidates], base_distances[:max_candidates], 0

    scene_global_indices = np.arange(db_start, db_end, dtype=np.int64)[valid_mask]
    scene_valid_coords = scene_coords[valid_mask]
    coord_dists = np.linalg.norm(scene_valid_coords - center, axis=1)
    within_radius = coord_dists <= float(expansion_radius_px)
    if not np.any(within_radius):
        return base_indices[:max_candidates], base_distances[:max_candidates], 0

    candidate_pool = list(zip(scene_global_indices[within_radius], coord_dists[within_radius]))
    candidate_pool.sort(key=lambda x: x[1])

    base_set = {int(idx) for idx in base_indices}
    extras = []
    for candidate_idx, _ in candidate_pool:
        candidate_idx = int(candidate_idx)
        if candidate_idx in base_set:
            continue
        extras.append(candidate_idx)
        if len(extras) >= max_expansion_candidates:
            break

    if not extras:
        return base_indices[:max_candidates], base_distances[:max_candidates], 0

    query_desc = np.asarray(query_desc, dtype=np.float32)
    extra_indices_arr = np.asarray(extras, dtype=np.int64)
    extra_scores = db_descs[extra_indices_arr] @ query_desc
    extra_distances = 1.0 - extra_scores.astype(np.float64)

    merged_pairs.extend((int(idx), float(dist)) for idx, dist in zip(extra_indices_arr, extra_distances))
    merged_pairs.sort(key=lambda x: x[1])

    deduped = []
    seen = set()
    for idx, dist in merged_pairs:
        if idx in seen:
            continue
        seen.add(idx)
        deduped.append((idx, dist))
        if len(deduped) >= max_candidates:
            break

    merged_indices = np.asarray([idx for idx, _ in deduped], dtype=np.int64)
    merged_distances = np.asarray([dist for _, dist in deduped], dtype=np.float64)
    extra_added = max(0, len(merged_indices) - len(base_indices))
    return merged_indices, merged_distances, extra_added


def apply_spatial_soft_penalty(
    candidate_indices,
    candidate_distances,
    coords,
    predicted_center,
    ref_px=SOFT_PENALTY_REF_PX,
    weight=SOFT_PENALTY_WEIGHT,
):
    """按到预测中心的距离给 soft penalty；不删除候选。"""
    inds = np.asarray(candidate_indices, dtype=np.int64)
    base_dists = np.asarray(candidate_distances, dtype=np.float64)
    debug = {
        "enabled": bool(ENABLE_SOFT_SPATIAL_PENALTY),
        "count": int(len(inds)),
        "applied": False,
        "mean_penalty": 0.0,
        "max_penalty": 0.0,
    }

    if (not ENABLE_SOFT_SPATIAL_PENALTY) or coords is None or predicted_center is None or len(inds) == 0:
        return base_dists, debug

    cand_coords = coords[inds]
    valid_mask = ~np.any(np.isnan(cand_coords), axis=1)
    if not np.any(valid_mask):
        return base_dists, debug

    center = np.asarray(predicted_center, dtype=np.float64)
    spatial_d = np.zeros(len(inds), dtype=np.float64)
    spatial_d.fill(float(ref_px))
    spatial_d[valid_mask] = np.linalg.norm(cand_coords[valid_mask] - center[None, :], axis=1)

    ref = max(float(ref_px), 1e-6)
    penalty = float(weight) * (spatial_d / ref) ** 2
    out_dists = base_dists + penalty

    debug["applied"] = True
    debug["mean_penalty"] = float(np.mean(penalty))
    debug["max_penalty"] = float(np.max(penalty))
    debug["ref_px"] = float(ref_px)
    return out_dists, debug
# Out:
# HMM 参数: alpha_sigma=0.3, emission_scale=5.0, window_size=3, expansion_radius_scale=1.8, expansion_radius_fallback_px=24.0, max_state_candidates=40, use_top1_fusion=False, fusion_hnsw_topn=5

# %% [markdown]
# ## 1. 加载 DB 与 Query（多轨迹）

# %%
print("加载 DB...")
db_names, db_descs = load_multi_netvlad_descriptors(DB_H5_PATHS)
db_descs = db_descs.astype(np.float32)
N_db, D = db_descs.shape
print(f"DB: {N_db} 条, 维度 {D}")

print("按轨迹加载 Query...")
query_per_traj = []
for h5_path in QUERY_H5_PATHS:
    names, descs = load_netvlad_descriptors(Path(h5_path))
    query_per_traj.append((names, descs.astype(np.float32)))

query_names = []
query_descs_list = []
for _, (names, descs) in enumerate(query_per_traj):
    query_names.extend(names)
    query_descs_list.append(descs)
query_descs = np.vstack(query_descs_list)
trajectory_ranges = get_query_trajectory_ranges(QUERY_H5_PATHS)
n_queries = query_descs.shape[0]
print(f"Query: {n_queries} 条, 共 {len(trajectory_ranges)} 条轨迹")
db_scene_ranges = get_db_scene_ranges(DB_H5_PATHS, db_names)
# Out:
# 加载 DB...
# DB: 11009 条, 维度 4096
# 按轨迹加载 Query...
# Query: 5988 条, 共 15 条轨迹

# %% [markdown]
# ## 2. DB 坐标（供 HMM 转移约束）与坐标法 GT@25

# %%
print("构建 database_coords（GDAL + id_startx_starty）...")
database_coords = build_database_coords(db_names, db_scene_ranges, DATASETS_BASE)
n_valid = np.sum(~np.any(np.isnan(database_coords), axis=1))
print(f"有效坐标: {n_valid}/{N_db}")

print("构建坐标法 GT@25（每 query 方圆 25 张）...")
gt_9_list, gt_25_ordered = build_gt_9_for_all_trajectories(
    trajectory_ranges,
    db_scene_ranges,
    db_names,
    DATASETS_BASE,
)
n_with_gt = sum(1 for s in gt_9_list if len(s) > 0)
print(f"有 GT 的 query 数: {n_with_gt}/{len(gt_9_list)}")
if n_with_gt > 0:
    sizes = [len(s) for s in gt_9_list if len(s) > 0]
    print(f"GT 集合大小: min={min(sizes)}, max={max(sizes)}, mean={sum(sizes)/len(sizes):.1f}  (若 max>9 说明已按 25 张生成)")
    i0 = next(i for i in range(len(gt_9_list)) if len(gt_9_list[i]) > 0)
    try:
        if i0 < len(gt_25_ordered) and gt_25_ordered[i0] and isinstance(gt_25_ordered[i0][0], (int, np.integer)):
            gt0 = list(gt_25_ordered[i0])
        else:
            gt0 = sorted(gt_9_list[i0])
    except NameError:
        gt0 = sorted(gt_9_list[i0])
    print(f"\n第一张有 GT 的 query（index={i0}）的 25 张 GT 图片:")
    for j, idx in enumerate(gt0):
        idx = int(idx) if not isinstance(idx, (int, np.integer)) else idx
        name = db_names[idx] if idx < len(db_names) else f"<{idx}>"
        print(f"  [{j+1:2d}] {name}")
# Out:
# 构建 database_coords（GDAL + id_startx_starty）...
# === database_coords 各场景（未算出坐标的会打印原因）===
#   [city1] 共 342 条 -> 有效坐标 342/342
#   [city2] 共 168 条 -> 有效坐标 168/168
#   [city3] 共 224 条 -> 有效坐标 224/224
#   [industry1] 共 868 条 -> 有效坐标 868/868
#   [industry2] 共 414 条 -> 有效坐标 414/414
#   [industry3] 共 1476 条 -> 有效坐标 1476/1476
#   [park1] 共 324 条 -> 有效坐标 324/324
#   [rural1] 共 1845 条 -> 有效坐标 1845/1845
#   [rural2] 共 1845 条 -> 有效坐标 1845/1845
#   [rural3] 共 399 条 -> 有效坐标 399/399
#   [school] 共 1178 条 -> 有效坐标 1178/1178
#   [suburbs1] 共 480 条 -> 有效坐标 480/480
#   [suburbs2] 共 468 条 -> 有效坐标 468/468
#   [village1] 共 285 条 -> 有效坐标 285/285
#   [village2] 共 693 条 -> 有效坐标 693/693
#   -> 合计有效坐标: 11009/11009
#
# 有效坐标: 11009/11009
# 构建坐标法 GT@25（每 query 方圆 25 张）...
# === 坐标法 GT@25 各轨迹（未算出 GT 的会打印原因）===
#
# --- 坐标法 GT 首帧诊断 [city1] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12123218.434142068
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4062398.742272254
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.91086
#   纬度 latitude  = 34.24388
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12123901.477057505
#   y_geo = 4061596.3503683605
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 2287.6214614151654
#   py (行) = 2687.3405730843588
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 1906, 2356
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [133, 134, 152, 153, 155, 156, 157, 173, 174, 175, 177, 178, 194, 195, 196, 197, 199, 215, 216, 217, 218, 219, 238, 239, 240]
# 对应的 db_names 示例 (前 3 个):
#     db_names[133] = tif/220_1756_1906.tif
#     db_names[134] = tif/221_1906_1906.tif
#     db_names[152] = tif/238_1606_2056.tif
# ---
#
#   [city1] 共 429 条 query -> 有 GT 的 429/429
#
# --- 坐标法 GT 首帧诊断 [city2] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12122606.937915787
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4062551.6163288243
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.90201
#   纬度 latitude  = 34.24669
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12122916.299563987
#   y_geo = 4061974.7608733126
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 1036.1023147544254
#   py (行) = 1931.9824425937115
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 512, tile_h = 512
# 距离 query 坐标最近的子图左上角 startx, starty = 706, 1606
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [343, 344, 345, 346, 357, 358, 359, 360, 361, 372, 373, 375, 376, 377, 378, 388, 389, 390, 391, 392, 393, 404, 405, 406, 408]
# 对应的 db_names 示例 (前 3 个):
#     db_names[343] = tif/101_556_1306.tif
#     db_names[344] = tif/102_706_1306.tif
#     db_names[345] = tif/103_856_1306.tif
# ---
#
#   [city2] 共 328 条 query -> 有 GT 的 328/328
#
# --- 坐标法 GT 首帧诊断 [city3] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12117256.345935825
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4055825.1578397285
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.85316
#   纬度 latitude  = 34.19611
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12117478.342438735
#   y_geo = 4055165.3032086804
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 743.5022791948704
#   py (行) = 2209.960137619448
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 406, 1756
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [541, 543, 544, 545, 559, 560, 561, 562, 577, 578, 579, 580, 581, 594, 595, 596, 598, 599, 612, 613, 614, 615, 630, 632, 633]
# 对应的 db_names 示例 (前 3 个):
#     db_names[541] = tif/129_256_1456.tif
#     db_names[543] = tif/130_406_1456.tif
#     db_names[544] = tif/131_556_1456.tif
# ---
#
#   [city3] 共 362 条 query -> 有 GT 的 362/362
#
# --- 坐标法 GT 首帧诊断 [industry1] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12116033.35348326
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4055442.972698303
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.85132
#   纬度 latitude  = 34.1952
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12117273.514575675
#   y_geo = 4055042.829631636
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 4153.500558314181
#   py (行) = 1340.1440030423498
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 3706, 1006
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [751, 752, 753, 754, 784, 785, 786, 787, 789, 790, 818, 819, 820, 822, 823, 824, 854, 856, 857, 858, 889, 890, 891, 1586, 1587]
# 对应的 db_names 示例 (前 3 个):
#     db_names[751] = tif_industry1/116_3556_706.tif
#     db_names[752] = tif_industry1/117_3706_706.tif
#     db_names[753] = tif_industry1/118_3856_706.tif
# ---
#
#   [industry1] 共 475 条 query -> 有 GT 的 475/475
#
# --- 坐标法 GT 首帧诊断 [industry2] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12111447.131786149
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4044818.2257666625
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.80706
#   纬度 latitude  = 34.11367
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12112346.513913166
#   y_geo = 4044075.361375706
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 3012.17655476212
#   py (行) = 2487.973281423313
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 2656, 2056
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [1763, 1764, 1765, 1787, 1788, 1790, 1791, 1792, 1813, 1814, 1815, 1816, 1817, 1839, 1840, 1841, 1842, 1843, 1864, 1865, 1866, 1868, 1869, 1891, 1892]
# 对应的 db_names 示例 (前 3 个):
#     db_names[1763] = tif_industry2/246_2506_1756.tif
#     db_names[1764] = tif_industry2/247_2656_1756.tif
#     db_names[1765] = tif_industry2/248_2806_1756.tif
# ---
#
#   [industry2] 共 262 条 query -> 有 GT 的 262/262
#
# --- 坐标法 GT 首帧诊断 [industry3] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12110682.761503298
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4044130.2925120965
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.80491
#   纬度 latitude  = 34.11074
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12112107.17700796
#   y_geo = 4043681.4128317335
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 4770.598456982045
#   py (行) = 1503.3708236824893
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 4456, 1156
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [2593, 2594, 2595, 2596, 2638, 2639, 2640, 2641, 2642, 2643, 2683, 2684, 2685, 2686, 2687, 2688, 2730, 2731, 2732, 2733, 2734, 2775, 2776, 2777, 2778]
# 对应的 db_names 示例 (前 3 个):
#     db_names[2593] = tif_industry3/191_4156_856.tif
#     db_names[2594] = tif_industry3/192_4306_856.tif
#     db_names[2595] = tif_industry3/193_4456_856.tif
# ---
#
#   [industry3] 共 624 条 query -> 有 GT 的 624/624
#
# --- 坐标法 GT 首帧诊断 [park1] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12121460.382491507
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4062933.80147025
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.896
#   纬度 latitude  = 34.24831
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12122247.26942432
#   y_geo = 4062192.9249843513
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 2635.4119112071853
#   py (行) = 2481.315465096788
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 2206, 2056
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [3594, 3595, 3596, 3614, 3615, 3616, 3617, 3618, 3633, 3634, 3636, 3637, 3638, 3639, 3653, 3654, 3655, 3656, 3658, 3659, 3674, 3675, 3676, 3677, 3695]
# 对应的 db_names 示例 (前 3 个):
#     db_names[3594] = tif_park1/193_2056_1756.tif
#     db_names[3595] = tif_park1/194_2206_1756.tif
#     db_names[3596] = tif_park1/195_2356_1756.tif
# ---
#
#   [park1] 共 398 条 query -> 有 GT 的 398/398
#
# --- 坐标法 GT 首帧诊断 [rural1] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12126734.537443187
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4044971.0998232327
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.94451
#   纬度 latitude  = 34.1144
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12127647.3779227
#   y_geo = 4044173.5145016657
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 3057.250759195328
#   py (行) = 2671.2425496106803
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 2656, 2356
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [5119, 5120, 5166, 5167, 5168, 5169, 5170, 5217, 5218, 5219, 5220, 5221, 5266, 5267, 5268, 5269, 5270, 5316, 5317, 5318, 5319, 5320, 5367, 5368, 5369]
# 对应的 db_names 示例 (前 3 个):
#     db_names[5119] = tif_rural1/512_2656_1906.tif
#     db_names[5120] = tif_rural1/513_2806_1906.tif
#     db_names[5166] = tif_rural1/555_2356_2056.tif
# ---
#
#   [rural1] 共 244 条 query -> 有 GT 的 244/244
#
# --- 坐标法 GT 首帧诊断 [rural2] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12126734.537443187
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4044971.0998232327
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.94435
#   纬度 latitude  = 34.11432
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12127629.566804174
#   y_geo = 4044162.757953378
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 2997.5984356415793
#   py (行) = 2707.267973720661
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 2656, 2356
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [6964, 7011, 7012, 7013, 7014, 7062, 7063, 7064, 7065, 7066, 7110, 7111, 7112, 7113, 7114, 7115, 7161, 7162, 7163, 7164, 7165, 7211, 7212, 7213, 7214]
# 对应的 db_names 示例 (前 3 个):
#     db_names[6964] = tif_rural2/512_2656_1906.tif
#     db_names[7011] = tif_rural2/555_2356_2056.tif
#     db_names[7012] = tif_rural2/556_2506_2056.tif
# ---
#
#   [rural2] 共 418 条 query -> 有 GT 的 418/418
#
# --- 坐标法 GT 首帧诊断 [rural3] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12115421.857256979
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4044971.0998232327
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.84315
#   纬度 latitude  = 34.11471
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12116364.034335895
#   y_geo = 4044215.1962223733
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 3155.5037867584324
#   py (行) = 2531.643709355843
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 2806, 2206
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [7646, 7647, 7668, 7669, 7670, 7672, 7673, 7691, 7692, 7694, 7695, 7696, 7714, 7716, 7717, 7718, 7719, 7739, 7740, 7741, 7742, 7743, 7763, 7764, 7765]
# 对应的 db_names 示例 (前 3 个):
#     db_names[7646] = tif_rural3/227_2656_1756.tif
#     db_names[7647] = tif_rural3/228_2806_1756.tif
#     db_names[7668] = tif_rural3/247_2506_1906.tif
# ---
#
#   [rural3] 共 429 条 query -> 有 GT 的 429/429
#
# --- 坐标法 GT 首帧诊断 [school] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12106096.539806187
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4034117.041806739
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.75627
#   纬度 latitude  = 34.03222
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12106692.596975774
#   y_geo = 4033129.2058731313
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 1996.2920960876288
#   py (行) = 3308.422693515066
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 1606, 2956
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [8616, 8617, 8656, 8657, 8658, 8659, 8661, 8698, 8699, 8700, 8701, 8702, 8740, 8741, 8742, 8743, 8744, 8783, 8784, 8785, 8786, 8787, 8825, 8827, 8828]
# 对应的 db_names 示例 (前 3 个):
#     db_names[8616] = tif_school/580_1606_2506.tif
#     db_names[8617] = tif_school/581_1756_2506.tif
#     db_names[8656] = tif_school/616_1306_2656.tif
# ---
#
#   [school] 共 533 条 query -> 有 GT 的 533/533
#
# --- 坐标法 GT 首帧诊断 [suburbs1] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12121001.760321796
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4046270.5293040816
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.896046
#   纬度 latitude  = 34.1259659
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12122252.390120894
#   y_geo = 4045728.7361077066
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 4188.5619542213635
#   py (行) = 1814.553252312962
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 3856, 1456
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [9197, 9198, 9199, 9200, 9229, 9230, 9231, 9232, 9233, 9234, 9262, 9263, 9264, 9265, 9266, 9267, 9296, 9297, 9298, 9299, 9300, 9330, 9331, 9332, 9333]
# 对应的 db_names 示例 (前 3 个):
#     db_names[9197] = tif_suburbs1/203_3556_1156.tif
#     db_names[9198] = tif_suburbs1/204_3706_1156.tif
#     db_names[9199] = tif_suburbs1/205_3856_1156.tif
# ---
#
#   [suburbs1] 共 227 条 query -> 有 GT 的 227/227
#
# --- 坐标法 GT 首帧诊断 [suburbs2] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12115880.47942669
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4044436.040625237
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.84394
#   纬度 latitude  = 34.11383
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12116451.976733621
#   y_geo = 4044096.874317125
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 1914.0371343152424
#   py (行) = 1135.9229528485594
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 1456, 706
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [9575, 9576, 9577, 9578, 9579, 9580, 9604, 9605, 9607, 9608, 9634, 9635, 9839, 9850, 9861, 9987, 9988, 9989, 9990, 10014, 10015, 10016, 10017, 10018, 10020]
# 对应的 db_names 示例 (前 3 个):
#     db_names[9575] = tif_suburbs2/111_1156_856.tif
#     db_names[9576] = tif_suburbs2/112_1306_856.tif
#     db_names[9577] = tif_suburbs2/113_1456_856.tif
# ---
#
#   [suburbs2] 共 488 条 query -> 有 GT 的 488/488
#
# --- 坐标法 GT 首帧诊断 [village1] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12125435.107962336
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4041607.870578686
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.9311
#   纬度 latitude  = 34.09292
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12126154.583551163
#   y_geo = 4041285.746528892
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 2409.6403912041505
#   py (行) = 1078.8456667831827
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 2056, 706
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [10037, 10038, 10039, 10040, 10239, 10240, 10241, 10242, 10243, 10259, 10261, 10262, 10263, 10264, 10279, 10280, 10281, 10283, 10284, 10285, 10301, 10302, 10303, 10305, 10306]
# 对应的 db_names 示例 (前 3 个):
#     db_names[10037] = tif_village1/106_1756_1006.tif
#     db_names[10038] = tif_village1/107_1906_1006.tif
#     db_names[10039] = tif_village1/108_2056_1006.tif
# ---
#
#   [village1] 共 310 条 query -> 有 GT 的 310/310
#
# --- 坐标法 GT 首帧诊断 [village2] ---
# 大图 mapbox geotransform (6 参数):
#   gt[0] 左上角 X (投影/经度): 12124747.17470777
#   gt[1] 像元宽:               0.2985821417389691
#   gt[2] 旋转(常为 0):         0.0
#   gt[3] 左上角 Y (投影/纬度): 4042372.240861537
#   gt[4] 旋转(常为 0):         0.0
#   gt[5] 像元高(常为负):       -0.2985821417389691
# 大图坐标系: EPSG:3857
# 第一张 query 图片的坐标 (uav_infos 第 1 行):
#   经度 longitude = 108.92904
#   纬度 latitude  = 34.09506
# 转换为大图投影坐标 (若大图非 WGS84 则先投影):
#   x_geo = 12125925.265400128
#   y_geo = 4041573.414932412
# 逆 geotransform 得到大图像素坐标:
#   px (列) = 3945.6167254236507
#   py (行) = 2675.3975454540114
# 子图尺寸 (从 tif 目录任取一张读取):
#   tile_w = 768, tile_h = 768
# 距离 query 坐标最近的子图左上角 startx, starty = 3556, 2356
# 距离 query 坐标最近的 25 张子图（按距离排序）对应的全局 DB 索引:
#   [10632, 10633, 10667, 10668, 10669, 10671, 10672, 10704, 10705, 10706, 10707, 10708, 10740, 10741, 10742, 10743, 10744, 10777, 10778, 10779, 10780, 10782, 10815, 10816, 10817]
# 对应的 db_names 示例 (前 3 个):
#     db_names[10632] = tif_village2/386_3556_1906.tif
#     db_names[10633] = tif_village2/387_3706_1906.tif
#     db_names[10667] = tif_village2/417_3256_2056.tif
# ---
#
#   [village2] 共 461 条 query -> 有 GT 的 461/461
#   -> 合计有 GT 的 query: 5988/5988
#
# 有 GT 的 query 数: 5988/5988
# GT 集合大小: min=25, max=25, mean=25.0  (若 max>9 说明已按 25 张生成)
#
# 第一张有 GT 的 query（index=0）的 25 张 GT 图片:
#   [ 1] tif/278_1906_2356.tif
#   [ 2] tif/259_1906_2206.tif
#   [ 3] tif/277_1756_2356.tif
#   [ 4] tif/279_2056_2356.tif
#   [ 5] tif/258_1756_2206.tif
#   [ 6] tif/260_2056_2206.tif
#   [ 7] tif/297_1906_2506.tif
#   [ 8] tif/240_1906_2056.tif
#   [ 9] tif/296_1756_2506.tif
#   [10] tif/298_2056_2506.tif
#   [11] tif/239_1756_2056.tif
#   [12] tif/241_2056_2056.tif
#   [13] tif/276_1606_2356.tif
#   [14] tif/280_2206_2356.tif
#   [15] tif/257_1606_2206.tif
#   [16] tif/261_2206_2206.tif
#   [17] tif/316_1906_2656.tif
#   [18] tif/295_1606_2506.tif
#   [19] tif/299_2206_2506.tif
#   [20] tif/315_1756_2656.tif
#   [21] tif/317_2056_2656.tif
#   [22] tif/238_1606_2056.tif
#   [23] tif/242_2206_2056.tif
#   [24] tif/221_1906_1906.tif
#   [25] tif/220_1756_1906.tif

# %% [markdown]
# ## 3. HNSW 索引（NetVLAD 已归一化，用内积）

# %%
K = 20
M = 32
ef_construction = 240
ef_search = 80

# 内积索引（归一化向量上等价于余弦）；Faiss 内积返回越大越相似
index = faiss.IndexHNSWFlat(D, M, faiss.METRIC_INNER_PRODUCT)
index.hnsw.efConstruction = ef_construction
index.hnsw.efSearch = ef_search
index.add(db_descs)
print(f"HNSW 索引已构建: M={M}, efConstruction={ef_construction}, efSearch={ef_search}, K={K}")
# Out:
# HNSW 索引已构建: M=32, efConstruction=240, efSearch=80, K=20

# %% [markdown]
# ## 3.1 候选集并集更新
#
# 新策略：在每一帧先取 `HNSW top20`，再把“上一帧 `top1` 所在子图的 `3x3` 邻域”加入，取并集后作为最终候选集；随后再做软惩罚和 HMM。

# %%
def merge_hnsw_with_prev_top1_nine_grid(
    base_indices,
    base_distances,
    query_desc,
    db_descs,
    db_names,
    db_start,
    db_end,
    prev_top1_global,
    max_candidates=MAX_STATE_CANDIDATES,
):
    """将 HNSW top-K 与上一帧 top1 所在子图的 3x3 邻域取并集。"""
    base_indices = np.asarray(base_indices, dtype=np.int64)
    base_distances = np.asarray(base_distances, dtype=np.float64)
    debug = {
        "base_count": int(len(base_indices)),
        "nine_grid_count": 0,
        "union_count": int(len(base_indices)),
        "anchor_global": None,
    }
    if base_indices.size == 0:
        return base_indices, base_distances, 0, debug
    if prev_top1_global is None or not (db_start <= int(prev_top1_global) < db_end):
        return base_indices[:max_candidates], base_distances[:max_candidates], 0, debug

    anchor_global = int(prev_top1_global)
    debug["anchor_global"] = anchor_global
    parsed_anchor = coords_gt_utils.parse_db_name(db_names[anchor_global])
    if parsed_anchor is None:
        return base_indices[:max_candidates], base_distances[:max_candidates], 0, debug

    _, anchor_startx, anchor_starty = parsed_anchor
    step = coords_gt_utils.TILE_GRID_STEP

    startxy_to_global = {}
    for global_idx in range(db_start, db_end):
        parsed = coords_gt_utils.parse_db_name(db_names[global_idx])
        if parsed is None:
            continue
        _, sx, sy = parsed
        startxy_to_global[(sx, sy)] = global_idx

    nine_grid = []
    for dy in (-1, 0, 1):
        for dx in (-1, 0, 1):
            key = (anchor_startx + dx * step, anchor_starty + dy * step)
            if key in startxy_to_global:
                nine_grid.append(int(startxy_to_global[key]))
    debug["nine_grid_count"] = int(len(nine_grid))

    merged_pairs = [(int(idx), float(dist)) for idx, dist in zip(base_indices, base_distances)]
    base_set = {int(idx) for idx in base_indices}
    extras = [idx for idx in nine_grid if idx not in base_set]

    if extras:
        query_desc = np.asarray(query_desc, dtype=np.float32)
        extra_indices_arr = np.asarray(extras, dtype=np.int64)
        extra_scores = db_descs[extra_indices_arr] @ query_desc
        extra_distances = 1.0 - extra_scores.astype(np.float64)
        merged_pairs.extend((int(idx), float(dist)) for idx, dist in zip(extra_indices_arr, extra_distances))

    merged_pairs.sort(key=lambda x: x[1])
    deduped = []
    seen = set()
    for idx, dist in merged_pairs:
        if idx in seen:
            continue
        seen.add(idx)
        deduped.append((idx, dist))
        if len(deduped) >= max_candidates:
            break

    merged_indices = np.asarray([idx for idx, _ in deduped], dtype=np.int64)
    merged_distances = np.asarray([dist for _, dist in deduped], dtype=np.float64)
    extra_added = max(0, len(merged_indices) - len(base_indices))
    debug["union_count"] = int(len(merged_indices))
    return merged_indices, merged_distances, extra_added, debug

# %% [markdown]
# ## 4. 逐轨迹运行 HNSW + HMM，并计算 Recall@1 / @5 / @10

# %%
# 检索方式：按场景检索（每条 query 只在该 query 所属场景的 DB 内检索，非全库检索）
use_coords = n_valid > 0
coords_for_hmm = database_coords if use_coords else None

index_per_scene = {}
for scene_name, db_start, db_end in db_scene_ranges:
    seg = db_descs[db_start:db_end]
    idx = faiss.IndexHNSWFlat(D, M, faiss.METRIC_INNER_PRODUCT)
    idx.hnsw.efConstruction = ef_construction
    idx.hnsw.efSearch = ef_search
    idx.add(seg)
    index_per_scene[scene_name] = (idx, db_start, db_end)

pred_hnsw = np.full(n_queries, -1, dtype=np.int64)
pred_hmm = np.full(n_queries, -1, dtype=np.int64)
store_topk = min(K, EVAL_TOPK)
topk_hnsw = np.full((n_queries, store_topk), -1, dtype=np.int64)
topk_hmm = np.full((n_queries, store_topk), -1, dtype=np.int64)
query_px_all = np.full(n_queries, np.nan, dtype=np.float64)
query_py_all = np.full(n_queries, np.nan, dtype=np.float64)
fusion_used_hmm = 0
fusion_fallback_hnsw = 0
query_idx = 0

for traj_idx, (scene_name, start, end) in enumerate(trajectory_ranges):
    idx_scene, db_start, db_end = index_per_scene.get(scene_name, (None, 0, 0))
    if idx_scene is None:
        query_idx += (end - start)
        continue
    q_descs = query_descs[start:end]
    n_frames = q_descs.shape[0]
    k_scene = min(K, db_end - db_start)
    D_t, I_local = idx_scene.search(q_descs, k_scene)
    I_t = I_local.astype(np.int64) + db_start
    dist_for_hmm = 1.0 - D_t.astype(np.float64)

    # 本轨迹 query 在大图像素坐标，用于 HMM 的真实位移/真实速度先验（4 fps）
    paths = get_scene_paths(scene_name, DATASETS_BASE)
    lats, lons = load_uav_infos(paths["uav_infos_path"])
    gt_tuple, _ = get_geotransform_and_srs(paths["mapbox_path"])
    n_use = min(len(lats), n_frames)
    query_px = [None] * n_frames
    query_py = [None] * n_frames
    frame_speeds = [None] * n_frames
    frame_displacements = []
    for f in range(n_use):
        px, py = lonlat_to_pixel(lons[f], lats[f], gt_tuple)
        query_px[f], query_py[f] = px, py
    for f in range(1, n_use):
        if query_px[f - 1] is None or query_px[f] is None:
            continue
        dx = query_px[f] - query_px[f - 1]
        dy = query_py[f] - query_py[f - 1]
        d_pix = float(np.hypot(dx, dy))
        frame_displacements.append(d_pix)
        frame_speeds[f] = d_pix * FPS
    valid_speeds = [s for s in frame_speeds if s is not None and np.isfinite(s) and s > 0]
    traj_mean_speed = float(np.mean(valid_speeds)) if valid_speeds else None
    if frame_displacements:
        disp_arr = np.asarray(frame_displacements, dtype=np.float64)
        median_disp = float(np.median(disp_arr))
        expansion_radius_px = max(EXPANSION_RADIUS_FALLBACK_PX, EXPANSION_RADIUS_SCALE * median_disp)
        print(
            f"[{scene_name}] 真实帧间像素位移统计: "
            f"mean={disp_arr.mean():.2f}px  median={median_disp:.2f}px  "
            f"p90={np.percentile(disp_arr, 90):.2f}px  max={disp_arr.max():.2f}px  "
            f"expansion_radius={expansion_radius_px:.2f}px  (n={len(disp_arr)})"
        )
    else:
        median_disp = None
        expansion_radius_px = EXPANSION_RADIUS_FALLBACK_PX
        print(f"[{scene_name}] 真实帧间像素位移统计: 无有效位移数据, expansion_radius={expansion_radius_px:.2f}px")

    verbose_hmm = (traj_idx == 0)
    if verbose_hmm:
        print("========== 第一个场景改进 HMM 过程（逐帧）==========")
        print(
            f"  window_size={WINDOW_SIZE}, expansion_radius_scale={EXPANSION_RADIUS_SCALE}, "
            f"expansion_radius_px={expansion_radius_px:.2f}, max_state_candidates={MAX_STATE_CANDIDATES}"
        )
        if traj_mean_speed is not None:
            print(f"  轨迹平均真实速度 = {traj_mean_speed:.4f} pixel/s (fps={FPS})")
        else:
            print(f"  未从真实坐标估计出有效速度，fps={FPS}，将退回到位移/均匀转移")
    hmm = WindowViterbiHMM(
        coords_for_hmm,
        MAX_STATE_CANDIDATES,
        uav_speed=traj_mean_speed,
        delta_t=FRAME_INTERVAL,
        window_size=WINDOW_SIZE,
        verbose=verbose_hmm,
    )
    for f in range(n_frames):
        if query_px[f] is not None and query_py[f] is not None:
            query_px_all[query_idx] = float(query_px[f])
            query_py_all[query_idx] = float(query_py[f])
        pred_hnsw[query_idx] = I_t[f, 0]
        n_top = min(store_topk, I_t.shape[1])
        topk_hnsw[query_idx, :n_top] = I_t[f, :n_top]

        base_inds = I_t[f]
        base_dists = dist_for_hmm[f]
        displacement = None
        frame_speed = frame_speeds[f]
        if f >= 1 and query_px[f - 1] is not None and query_px[f] is not None:
            displacement = (query_px[f] - query_px[f - 1], query_py[f] - query_py[f - 1])

        predicted_center = None
        # 按你的要求：预测中心 = 上一帧 query 真实坐标 + 当前位移
        if f >= 1 and query_px[f - 1] is not None and query_py[f - 1] is not None and displacement is not None:
            predicted_center = np.array(
                [query_px[f - 1] + displacement[0], query_py[f - 1] + displacement[1]],
                dtype=np.float64,
            )
        # 首帧或位移缺失时，退化为当前帧真实坐标
        elif query_px[f] is not None and query_py[f] is not None:
            predicted_center = np.array([query_px[f], query_py[f]], dtype=np.float64)

        # 最终候选集 = HNSW top-K 与上一帧 top1 所在子图 3x3 邻域的并集
        merged_inds, merged_dists, extra_added, merge_debug = merge_hnsw_with_prev_top1_nine_grid(
            base_inds,
            base_dists,
            q_descs[f],
            db_descs,
            db_names,
            db_start,
            db_end,
            hmm.prev_best_global,
        )

        # 在这个并集上做软惩罚，再送入 HMM
        penalized_merged_dists, penalty_debug_merged = apply_spatial_soft_penalty(
            merged_inds,
            merged_dists,
            coords_for_hmm,
            predicted_center,
        )
        hmm_top, window_debug = hmm.add_frame(
            merged_inds,
            penalized_merged_dists,
            return_top_k=store_topk,
            displacement=displacement,
            frame_speed=frame_speed,
            metadata={"extra_neighbors": extra_added, "frame_index": f},
            return_debug=True,
        )
        if verbose_hmm and (f < 5 or extra_added > 0):
            if penalty_debug_merged.get("applied", False):
                print(
                    f"  [soft-penalty] frame={f} mean={penalty_debug_merged.get('mean_penalty', 0.0):.4f} "
                    f"max={penalty_debug_merged.get('max_penalty', 0.0):.4f} ref_px={penalty_debug_merged.get('ref_px', SOFT_PENALTY_REF_PX)}"
                )
            print(
                f"  [merge-9grid] frame={f} base_candidates={len(base_inds)} "
                f"prev_top1={merge_debug['anchor_global']} nine_grid={merge_debug['nine_grid_count']} "
                f"union_candidates={len(merged_inds)} extra_candidates={extra_added} "
                f"window_length={window_debug['window_length']}"
            )

        hnsw_ranked = [int(x) for x in base_inds[:store_topk]]
        fused_ranking = [int(x) for x in hmm_top[:store_topk]] if hmm_top else hnsw_ranked.copy()
        warm_start_active = (f < 3 and len(gt_9_list[query_idx]) > 0)
        if USE_HMM_TOP1_FUSION and not warm_start_active and hmm_top:
            hnsw_topn = {int(x) for x in base_inds[: min(FUSION_HNSW_TOPN, len(base_inds))]}
            hmm_top1 = int(hmm_top[0])
            if hmm_top1 in hnsw_topn:
                fusion_used_hmm += 1
                fused_top1 = hmm_top1
                fusion_source = "HMM"
            else:
                fusion_fallback_hnsw += 1
                fused_top1 = int(base_inds[0])
                fusion_source = "HNSW"
            fused_ranking = [fused_top1]
            fused_ranking.extend(int(x) for x in hmm_top if int(x) != fused_top1)
            fused_ranking.extend(int(x) for x in hnsw_ranked if int(x) != fused_top1)
            deduped_ranking = []
            seen = set()
            for idx in fused_ranking:
                if idx in seen:
                    continue
                seen.add(idx)
                deduped_ranking.append(idx)
                if len(deduped_ranking) >= store_topk:
                    break
            fused_ranking = deduped_ranking
            if verbose_hmm and (f < 5 or fusion_source == "HNSW"):
                print(
                    f"  [fusion] frame={f} source={fusion_source} "
                    f"hmm_top1={hmm_top1} hnsw_top1={int(base_inds[0])} "
                    f"hnsw_top{FUSION_HNSW_TOPN}={list(base_inds[: min(FUSION_HNSW_TOPN, len(base_inds))])}"
                )
        pred_hmm[query_idx] = fused_ranking[0] if fused_ranking else -1
        topk_hmm[query_idx, :] = -1
        for j, idx in enumerate(fused_ranking[:store_topk]):
            topk_hmm[query_idx, j] = idx

        # 每场景前 3 帧用 GT 的 top1 做 warm-start，下一帧窗口解码将从该 GT 重新锚定
        if warm_start_active:
            gt_idx = gt_25_ordered[query_idx][0] if (query_idx < len(gt_25_ordered) and gt_25_ordered[query_idx]) else min(gt_9_list[query_idx])
            if verbose_hmm:
                gt_name = db_names[gt_idx] if 0 <= gt_idx < len(db_names) else "?"
                print(f"  [warm-start] 帧 f={f} 用 GT top1 替代: gt_idx={gt_idx} -> {gt_name}")
            pred_hmm[query_idx] = gt_idx
            topk_hmm[query_idx, :] = -1
            topk_hmm[query_idx, 0] = gt_idx
            rest = [x for x in fused_ranking if x != gt_idx][: max(0, store_topk - 1)]
            for j, x in enumerate(rest):
                topk_hmm[query_idx, j + 1] = x
            hmm.override_prev_best(gt_idx)
        query_idx += 1

assert query_idx == n_queries
print(
    f"Top1 融合统计: 使用 HMM top1 {fusion_used_hmm} 次, "
    f"回退到 HNSW top1 {fusion_fallback_hnsw} 次, "
    f"融合启用={USE_HMM_TOP1_FUSION}, HNSW topN={FUSION_HNSW_TOPN}"
)
# Out:
# [city1] 真实帧间像素位移统计: mean=16.24px  median=15.58px  p90=18.64px  max=21.23px  expansion_radius=28.04px  (n=428)
# ========== 第一个场景改进 HMM 过程（逐帧）==========
#   window_size=3, expansion_radius_scale=1.8, expansion_radius_px=28.04, max_state_candidates=40
#   轨迹平均真实速度 = 64.9603 pixel/s (fps=4.0)
#
# --- Window HMM Frame 0 ---
#   window_length = 1/3
#   candidate_counts = [20]
#   extra_neighbors = 0
#   displacement = None
#   frame_speed = None
#   predicted_center = None
#   Window HMM 输出 top-1 = 175, top-3 = [175, 174, 196]
#   best_path = [175]
#   [soft-penalty] frame=0 mean=0.0071 max=0.0230 ref_px=250.0
#   [merge-9grid] frame=0 base_candidates=20 prev_top1=None nine_grid=0 union_candidates=20 extra_candidates=0 window_length=1
#   [warm-start] 帧 f=0 用 GT top1 替代: gt_idx=196 -> tif/278_1906_2356.tif
#     [transition] prev_best_global=196, center=[2275.08691912 2744.51009573], motion_radius=15.5801, radius=31.2, sigma=95.3115, displacement=(-14.913080883758084, 4.51009573291185), frame_speed=62.32058343315351
#     [transition] log_trans: shape=(1, 22), 有效元素=22, max=-0.0134, min=-27.6310
#
# --- Window HMM Frame 1 ---
#   window_length = 1/3
#   candidate_counts = [22]
#   extra_neighbors = 2
#   displacement = (-14.913080883758084, 4.51009573291185)
#   frame_speed = 62.32058343315351
#   predicted_center = None
#   Window HMM 输出 top-1 = 196, top-3 = [196, 195, 175]
#   best_path = [196]
#   [soft-penalty] frame=1 mean=0.0184 max=0.1388 ref_px=250.0
#   [merge-9grid] frame=1 base_candidates=20 prev_top1=196 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=1
#   [warm-start] 帧 f=1 用 GT top1 替代: gt_idx=196 -> tif/278_1906_2356.tif
#     [transition] prev_best_global=196, center=[2275.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=95.3115, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(1, 22), 有效元素=22, max=-0.0122, min=-27.6310
#
# --- Window HMM Frame 2 ---
#   window_length = 1/3
#   candidate_counts = [22]
#   extra_neighbors = 2
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 196, top-3 = [196, 195, 175]
#   best_path = [196]
#   [soft-penalty] frame=2 mean=0.0132 max=0.1414 ref_px=250.0
#   [merge-9grid] frame=2 base_candidates=20 prev_top1=196 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=1
#   [warm-start] 帧 f=2 用 GT top1 替代: gt_idx=196 -> tif/278_1906_2356.tif
#     [transition] prev_best_global=196, center=[2271.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=95.3115, displacement=(-18.641351109376956, 0.0), frame_speed=74.56540443750782
#     [transition] log_trans: shape=(1, 22), 有效元素=22, max=-0.0191, min=-27.6310
#
# --- Window HMM Frame 3 ---
#   window_length = 1/3
#   candidate_counts = [22]
#   extra_neighbors = 2
#   displacement = (-18.641351109376956, 0.0)
#   frame_speed = 74.56540443750782
#   predicted_center = None
#   Window HMM 输出 top-1 = 196, top-3 = [196, 195, 175]
#   best_path = [196]
#   [soft-penalty] frame=3 mean=0.0133 max=0.1398 ref_px=250.0
#   [merge-9grid] frame=3 base_candidates=20 prev_top1=196 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=1
#     [transition] prev_best_global=175, center=[2275.08691911 2594.51009519], motion_radius=15.5801, radius=31.2, sigma=100.6231, displacement=(-14.913080889996763, 4.510095185501086), frame_speed=62.32058282318826
#     [transition] log_trans: shape=(22, 22), 有效元素=484, max=-0.0120, min=-27.6310
#
# --- Window HMM Frame 4 ---
#   window_length = 2/3
#   candidate_counts = [22, 22]
#   extra_neighbors = 2
#   displacement = (-14.913080889996763, 4.510095185501086)
#   frame_speed = 62.32058282318826
#   predicted_center = None
#   Window HMM 输出 top-1 = 175, top-3 = [175, 174, 196]
#   best_path = [175, 175]
#   [soft-penalty] frame=4 mean=0.0132 max=0.1453 ref_px=250.0
#   [merge-9grid] frame=4 base_candidates=20 prev_top1=196 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=2
#     [transition] prev_best_global=175, center=[2275.08691911 2594.51009519], motion_radius=15.5801, radius=31.2, sigma=100.6231, displacement=(-14.913080889996763, 4.510095185501086), frame_speed=62.32058282318826
#     [transition] log_trans: shape=(22, 22), 有效元素=484, max=-0.0120, min=-27.6310
#     [transition] prev_best_global=175, center=[2271.35864889 2590.        ], motion_radius=18.6414, radius=37.3, sigma=127.2792, displacement=(-18.641351109376956, 0.0), frame_speed=74.56540443750782
#     [transition] log_trans: shape=(22, 22), 有效元素=484, max=-0.0107, min=-27.6310
#
# --- Window HMM Frame 5 ---
#   window_length = 3/3
#   candidate_counts = [22, 22, 22]
#   extra_neighbors = 2
#   displacement = (-18.641351109376956, 0.0)
#   frame_speed = 74.56540443750782
#   predicted_center = None
#   Window HMM 输出 top-1 = 175, top-3 = [175, 174, 196]
#   best_path = [175, 175, 175]
#   [soft-penalty] frame=5 mean=0.0157 max=0.1301 ref_px=250.0
#   [merge-9grid] frame=5 base_candidates=20 prev_top1=175 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=175, center=[2271.35864889 2590.        ], motion_radius=18.6414, radius=37.3, sigma=127.2792, displacement=(-18.641351109376956, 0.0), frame_speed=74.56540443750782
#     [transition] log_trans: shape=(22, 22), 有效元素=484, max=-0.0107, min=-27.6310
#     [transition] prev_best_global=175, center=[2275.08691911 2590.        ], motion_radius=14.9131, radius=29.8, sigma=127.2792, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 22), 有效元素=484, max=-0.0069, min=-27.6310
#
# --- Window HMM Frame 6 ---
#   window_length = 3/3
#   candidate_counts = [22, 22, 22]
#   extra_neighbors = 2
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 175, top-3 = [175, 174, 196]
#   best_path = [175, 175, 175]
#   [soft-penalty] frame=6 mean=0.0124 max=0.1285 ref_px=250.0
#   [merge-9grid] frame=6 base_candidates=20 prev_top1=175 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=175, center=[2275.08691911 2590.        ], motion_radius=14.9131, radius=29.8, sigma=127.2792, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 22), 有效元素=484, max=-0.0069, min=-27.6310
#     [transition] prev_best_global=175, center=[2275.08691911 2594.51009465], motion_radius=15.5801, radius=31.2, sigma=127.2792, displacement=(-14.913080889996763, 4.510094650566771), frame_speed=62.32058220378339
#     [transition] log_trans: shape=(22, 22), 有效元素=484, max=-0.0075, min=-27.6310
#
# --- Window HMM Frame 7 ---
#   window_length = 3/3
#   candidate_counts = [22, 22, 22]
#   extra_neighbors = 2
#   displacement = (-14.913080889996763, 4.510094650566771)
#   frame_speed = 62.32058220378339
#   predicted_center = None
#   Window HMM 输出 top-1 = 175, top-3 = [175, 174, 196]
#   best_path = [175, 175, 175]
#   [soft-penalty] frame=7 mean=0.0181 max=0.1521 ref_px=250.0
#   [merge-9grid] frame=7 base_candidates=20 prev_top1=175 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=174, center=[2125.08691911 2594.51009465], motion_radius=15.5801, radius=31.2, sigma=127.2792, displacement=(-14.913080889996763, 4.510094650566771), frame_speed=62.32058220378339
#     [transition] log_trans: shape=(22, 22), 有效元素=484, max=-0.0075, min=-27.6310
#     [transition] prev_best_global=174, center=[2125.08691911 2590.        ], motion_radius=14.9131, radius=29.8, sigma=113.9511, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 23), 有效元素=506, max=-0.0086, min=-10.9271
#
# --- Window HMM Frame 8 ---
#   window_length = 3/3
#   candidate_counts = [22, 22, 23]
#   extra_neighbors = 3
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 174, top-3 = [174, 173, 195]
#   best_path = [174, 174, 174]
#   [soft-penalty] frame=8 mean=0.0062 max=0.0165 ref_px=250.0
#   [merge-9grid] frame=8 base_candidates=20 prev_top1=175 nine_grid=9 union_candidates=23 extra_candidates=3 window_length=3
#     [transition] prev_best_global=174, center=[2125.08691911 2590.        ], motion_radius=14.9131, radius=29.8, sigma=113.9511, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 23), 有效元素=506, max=-0.0086, min=-10.9271
#     [transition] prev_best_global=174, center=[2121.35864889 2594.51009412], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.6413511093765, 4.510094124990246), frame_speed=76.71671736453004
#     [transition] log_trans: shape=(23, 20), 有效元素=460, max=-0.0182, min=-10.2340
#
# --- Window HMM Frame 9 ---
#   window_length = 3/3
#   candidate_counts = [22, 23, 20]
#   extra_neighbors = 0
#   displacement = (-18.6413511093765, 4.510094124990246)
#   frame_speed = 76.71671736453004
#   predicted_center = None
#   Window HMM 输出 top-1 = 174, top-3 = [174, 173, 195]
#   best_path = [174, 174, 174]
#     [transition] prev_best_global=193, center=[1821.35864889 2744.51009412], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.6413511093765, 4.510094124990246), frame_speed=76.71671736453004
#     [transition] log_trans: shape=(23, 20), 有效元素=460, max=-0.0182, min=-21.0457
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0110, min=-20.6728
#
# --- Window HMM Frame 10 ---
#   window_length = 3/3
#   candidate_counts = [23, 20, 20]
#   extra_neighbors = 0
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 172, 214]
#   best_path = [193, 193, 193]
#     [transition] prev_best_global=174, center=[2125.08691911 2590.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0110, min=-14.0136
#     [transition] prev_best_global=174, center=[2125.08691912 2590.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.91308088375854, 0.0), frame_speed=59.65232353503416
#     [transition] log_trans: shape=(20, 22), 有效元素=440, max=-0.0110, min=-27.6310
#
# --- Window HMM Frame 11 ---
#   window_length = 3/3
#   candidate_counts = [20, 20, 22]
#   extra_neighbors = 2
#   displacement = (-14.91308088375854, 0.0)
#   frame_speed = 59.65232353503416
#   predicted_center = None
#   Window HMM 输出 top-1 = 174, top-3 = [174, 173, 153]
#   best_path = [174, 174, 174]
#   [soft-penalty] frame=11 mean=0.0103 max=0.1071 ref_px=250.0
#   [merge-9grid] frame=11 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=174, center=[2125.08691912 2590.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.91308088375854, 0.0), frame_speed=59.65232353503416
#     [transition] log_trans: shape=(20, 22), 有效元素=440, max=-0.0110, min=-27.6310
#     [transition] prev_best_global=174, center=[2121.35864888 2594.51009358], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.64135111561518, 4.510093577579028), frame_speed=76.71671687387743
#     [transition] log_trans: shape=(22, 20), 有效元素=440, max=-0.0182, min=-27.6310
#
# --- Window HMM Frame 12 ---
#   window_length = 3/3
#   candidate_counts = [20, 22, 20]
#   extra_neighbors = 0
#   displacement = (-18.64135111561518, 4.510093577579028)
#   frame_speed = 76.71671687387743
#   predicted_center = None
#   Window HMM 输出 top-1 = 174, top-3 = [174, 173, 195]
#   best_path = [174, 174, 174]
#     [transition] prev_best_global=174, center=[2121.35864888 2594.51009358], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.64135111561518, 4.510093577579028), frame_speed=76.71671687387743
#     [transition] log_trans: shape=(22, 20), 有效元素=440, max=-0.0182, min=-27.6310
#     [transition] prev_best_global=174, center=[2125.08691912 2590.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.91308088375854, 0.0), frame_speed=59.65232353503416
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0110, min=-10.4593
#
# --- Window HMM Frame 13 ---
#   window_length = 3/3
#   candidate_counts = [22, 20, 20]
#   extra_neighbors = 0
#   displacement = (-14.91308088375854, 0.0)
#   frame_speed = 59.65232353503416
#   predicted_center = None
#   Window HMM 输出 top-1 = 174, top-3 = [174, 173, 195]
#   best_path = [174, 174, 174]
#     [transition] prev_best_global=193, center=[1825.08691912 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.91308088375854, 0.0), frame_speed=59.65232353503416
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0110, min=-15.1182
#     [transition] prev_best_global=193, center=[1825.0869191 2740.       ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080896234987, 0.0), frame_speed=59.65232358493995
#     [transition] log_trans: shape=(20, 21), 有效元素=420, max=-0.0110, min=-27.6310
#
# --- Window HMM Frame 14 ---
#   window_length = 3/3
#   candidate_counts = [20, 20, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080896234987, 0.0)
#   frame_speed = 59.65232358493995
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=14 mean=0.0102 max=0.1143 ref_px=250.0
#   [merge-9grid] frame=14 base_candidates=20 prev_top1=174 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=174, center=[2125.0869191 2590.       ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080896234987, 0.0), frame_speed=59.65232358493995
#     [transition] log_trans: shape=(20, 21), 有效元素=420, max=-0.0110, min=-27.6310
#     [transition] prev_best_global=174, center=[2121.3586489  2594.51009305], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.641351103138277, 4.510093053561377), frame_speed=76.71671633246639
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0182, min=-27.6310
#
# --- Window HMM Frame 15 ---
#   window_length = 3/3
#   candidate_counts = [20, 21, 21]
#   extra_neighbors = 1
#   displacement = (-18.641351103138277, 4.510093053561377)
#   frame_speed = 76.71671633246639
#   predicted_center = None
#   Window HMM 输出 top-1 = 174, top-3 = [174, 173, 195]
#   best_path = [174, 174, 174]
#   [soft-penalty] frame=15 mean=0.0147 max=0.1852 ref_px=250.0
#   [merge-9grid] frame=15 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1821.3586489  2744.51009305], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.641351103138277, 4.510093053561377), frame_speed=76.71671633246639
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0182, min=-27.6310
#     [transition] prev_best_global=193, center=[1825.0869191 2740.       ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080896234987, 0.0), frame_speed=59.65232358493995
#     [transition] log_trans: shape=(21, 22), 有效元素=462, max=-0.0110, min=-15.1182
#
# --- Window HMM Frame 16 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 22]
#   extra_neighbors = 2
#   displacement = (-14.913080896234987, 0.0)
#   frame_speed = 59.65232358493995
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=16 mean=0.0060 max=0.0202 ref_px=250.0
#   [merge-9grid] frame=16 base_candidates=20 prev_top1=174 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=193, center=[1825.0869191 2740.       ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080896234987, 0.0), frame_speed=59.65232358493995
#     [transition] log_trans: shape=(21, 22), 有效元素=462, max=-0.0110, min=-15.1182
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 21), 有效元素=462, max=-0.0110, min=-11.7849
#
# --- Window HMM Frame 17 ---
#   window_length = 3/3
#   candidate_counts = [21, 22, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=17 mean=0.0058 max=0.0193 ref_px=250.0
#   [merge-9grid] frame=17 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 21), 有效元素=462, max=-0.0110, min=-11.7849
#     [transition] prev_best_global=193, center=[1821.35864889 2744.51009251], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.641351109376956, 4.510092507710851), frame_speed=76.71671584328193
#     [transition] log_trans: shape=(21, 22), 有效元素=462, max=-0.0182, min=-18.0631
#
# --- Window HMM Frame 18 ---
#   window_length = 3/3
#   candidate_counts = [22, 21, 22]
#   extra_neighbors = 2
#   displacement = (-18.641351109376956, 4.510092507710851)
#   frame_speed = 76.71671584328193
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=18 mean=0.0063 max=0.0230 ref_px=250.0
#   [merge-9grid] frame=18 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=193, center=[1821.35864889 2744.51009251], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.641351109376956, 4.510092507710851), frame_speed=76.71671584328193
#     [transition] log_trans: shape=(21, 22), 有效元素=462, max=-0.0182, min=-18.0631
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=127.2792, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 21), 有效元素=462, max=-0.0069, min=-27.6310
#
# --- Window HMM Frame 19 ---
#   window_length = 3/3
#   candidate_counts = [21, 22, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=19 mean=0.0122 max=0.1149 ref_px=250.0
#   [merge-9grid] frame=19 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=127.2792, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 21), 有效元素=462, max=-0.0069, min=-27.6310
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=127.2792, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0069, min=-27.6310
#
# --- Window HMM Frame 20 ---
#   window_length = 3/3
#   candidate_counts = [22, 21, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=20 mean=0.0188 max=0.1815 ref_px=250.0
#   [merge-9grid] frame=20 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=127.2792, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0069, min=-27.6310
#     [transition] prev_best_global=193, center=[1821.35864889 2744.51009198], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.64135110937673, 4.510091983693201), frame_speed=76.7167153503782
#     [transition] log_trans: shape=(21, 20), 有效元素=420, max=-0.0182, min=-27.6310
#
# --- Window HMM Frame 21 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 20]
#   extra_neighbors = 0
#   displacement = (-18.64135110937673, 4.510091983693201)
#   frame_speed = 76.7167153503782
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#     [transition] prev_best_global=193, center=[1821.35864889 2744.51009198], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.64135110937673, 4.510091983693201), frame_speed=76.7167153503782
#     [transition] log_trans: shape=(21, 20), 有效元素=420, max=-0.0182, min=-27.6310
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0110, min=-11.7849
#
# --- Window HMM Frame 22 ---
#   window_length = 3/3
#   candidate_counts = [21, 20, 20]
#   extra_neighbors = 0
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#     [transition] prev_best_global=172, center=[1825.08691911 2590.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0110, min=-15.1182
#     [transition] prev_best_global=172, center=[1825.08691912 2590.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080883758312, 0.0), frame_speed=59.65232353503325
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0110, min=-15.1182
#
# --- Window HMM Frame 23 ---
#   window_length = 3/3
#   candidate_counts = [20, 20, 20]
#   extra_neighbors = 0
#   displacement = (-14.913080883758312, 0.0)
#   frame_speed = 59.65232353503325
#   predicted_center = None
#   Window HMM 输出 top-1 = 172, top-3 = [172, 193, 171]
#   best_path = [172, 172, 172]
#     [transition] prev_best_global=193, center=[1825.08691912 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080883758312, 0.0), frame_speed=59.65232353503325
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0110, min=-11.7849
#     [transition] prev_best_global=193, center=[1821.35864888 2744.51009143], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.64135111561518, 4.510091433163325), frame_speed=76.71671485679147
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0182, min=-15.4247
#
# --- Window HMM Frame 24 ---
#   window_length = 3/3
#   candidate_counts = [20, 20, 20]
#   extra_neighbors = 0
#   displacement = (-18.64135111561518, 4.510091433163325)
#   frame_speed = 76.71671485679147
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#     [transition] prev_best_global=193, center=[1821.35864888 2744.51009143], motion_radius=19.1792, radius=38.4, sigma=100.6231, displacement=(-18.64135111561518, 4.510091433163325), frame_speed=76.71671485679147
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0182, min=-15.4247
#     [transition] prev_best_global=193, center=[1825.08691912 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080883758312, 0.0), frame_speed=59.65232353503325
#     [transition] log_trans: shape=(20, 21), 有效元素=420, max=-0.0110, min=-27.6310
#
# --- Window HMM Frame 25 ---
#   window_length = 3/3
#   candidate_counts = [20, 20, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080883758312, 0.0)
#   frame_speed = 59.65232353503325
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=25 mean=0.0125 max=0.1311 ref_px=250.0
#   [merge-9grid] frame=25 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691912 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080883758312, 0.0), frame_speed=59.65232353503325
#     [transition] log_trans: shape=(20, 21), 有效元素=420, max=-0.0110, min=-27.6310
#     [transition] prev_best_global=193, center=[1825.0869191 2740.       ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080896235215, 0.0), frame_speed=59.65232358494086
#     [transition] log_trans: shape=(21, 20), 有效元素=420, max=-0.0110, min=-11.7849
#
# --- Window HMM Frame 26 ---
#   window_length = 3/3
#   candidate_counts = [20, 21, 20]
#   extra_neighbors = 0
#   displacement = (-14.913080896235215, 0.0)
#   frame_speed = 59.65232358494086
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#     [transition] prev_best_global=193, center=[1825.0869191 2740.       ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080896235215, 0.0), frame_speed=59.65232358494086
#     [transition] log_trans: shape=(21, 20), 有效元素=420, max=-0.0110, min=-11.7849
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=100.6231, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0172, min=-11.9568
#
# --- Window HMM Frame 27 ---
#   window_length = 3/3
#   candidate_counts = [21, 20, 20]
#   extra_neighbors = 0
#   displacement = (-18.64135110937673, 0.0)
#   frame_speed = 74.56540443750691
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=100.6231, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(20, 20), 有效元素=400, max=-0.0172, min=-11.9568
#     [transition] prev_best_global=193, center=[1825.08691911 2744.51009091], motion_radius=15.5801, radius=31.2, sigma=100.6231, displacement=(-14.913080889996763, 4.510090910705458), frame_speed=62.320577873368876
#     [transition] log_trans: shape=(20, 21), 有效元素=420, max=-0.0120, min=-21.2152
#
# --- Window HMM Frame 28 ---
#   window_length = 3/3
#   candidate_counts = [20, 20, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080889996763, 4.510090910705458)
#   frame_speed = 62.320577873368876
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=28 mean=0.0069 max=0.0288 ref_px=250.0
#   [merge-9grid] frame=28 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2744.51009091], motion_radius=15.5801, radius=31.2, sigma=100.6231, displacement=(-14.913080889996763, 4.510090910705458), frame_speed=62.320577873368876
#     [transition] log_trans: shape=(20, 21), 有效元素=420, max=-0.0120, min=-21.2152
#     [transition] prev_best_global=193, center=[1825.08691912 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080883758312, 0.0), frame_speed=59.65232353503325
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0110, min=-21.3476
#
# --- Window HMM Frame 29 ---
#   window_length = 3/3
#   candidate_counts = [20, 21, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080883758312, 0.0)
#   frame_speed = 59.65232353503325
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=29 mean=0.0071 max=0.0277 ref_px=250.0
#   [merge-9grid] frame=29 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691912 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080883758312, 0.0), frame_speed=59.65232353503325
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0110, min=-21.3476
#     [transition] prev_best_global=193, center=[1821.35864888 2740.        ], motion_radius=18.6414, radius=37.3, sigma=100.6231, displacement=(-18.64135111561518, 0.0), frame_speed=74.56540446246072
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0172, min=-21.1332
#
# --- Window HMM Frame 30 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 21]
#   extra_neighbors = 1
#   displacement = (-18.64135111561518, 0.0)
#   frame_speed = 74.56540446246072
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=30 mean=0.0073 max=0.0263 ref_px=250.0
#   [merge-9grid] frame=30 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1821.35864888 2740.        ], motion_radius=18.6414, radius=37.3, sigma=100.6231, displacement=(-18.64135111561518, 0.0), frame_speed=74.56540446246072
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0172, min=-21.1332
#     [transition] prev_best_global=193, center=[1825.08691912 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.91308088375854, 0.0), frame_speed=59.65232353503416
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0110, min=-21.3476
#
# --- Window HMM Frame 31 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 21]
#   extra_neighbors = 1
#   displacement = (-14.91308088375854, 0.0)
#   frame_speed = 59.65232353503416
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=31 mean=0.0075 max=0.0253 ref_px=250.0
#   [merge-9grid] frame=31 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691912 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.91308088375854, 0.0), frame_speed=59.65232353503416
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0110, min=-21.3476
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0110, min=-21.3476
#
# --- Window HMM Frame 32 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=32 mean=0.0075 max=0.0242 ref_px=250.0
#   [merge-9grid] frame=32 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0110, min=-21.3476
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=100.6231, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0172, min=-15.2901
#
# --- Window HMM Frame 33 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 21]
#   extra_neighbors = 1
#   displacement = (-18.64135110937673, 0.0)
#   frame_speed = 74.56540443750691
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=33 mean=0.0078 max=0.0244 ref_px=250.0
#   [merge-9grid] frame=33 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=100.6231, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0172, min=-15.2901
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0110, min=-27.6310
#
# --- Window HMM Frame 34 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=34 mean=0.0205 max=0.2685 ref_px=250.0
#   [merge-9grid] frame=34 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=100.6231, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0110, min=-27.6310
#     [transition] prev_best_global=193, center=[1825.08691911 2744.51009036], motion_radius=15.5801, radius=31.2, sigma=127.2792, displacement=(-14.913080889996763, 4.5100903648540225), frame_speed=62.32057724132353
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0075, min=-27.6310
#
# --- Window HMM Frame 35 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 21]
#   extra_neighbors = 1
#   displacement = (-14.913080889996763, 4.5100903648540225)
#   frame_speed = 62.32057724132353
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=35 mean=0.0249 max=0.1898 ref_px=250.0
#   [merge-9grid] frame=35 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2744.51009036], motion_radius=15.5801, radius=31.2, sigma=127.2792, displacement=(-14.913080889996763, 4.5100903648540225), frame_speed=62.32057724132353
#     [transition] log_trans: shape=(21, 21), 有效元素=441, max=-0.0075, min=-27.6310
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=135.0000, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(21, 22), 有效元素=462, max=-0.0095, min=-27.6310
#
# --- Window HMM Frame 36 ---
#   window_length = 3/3
#   candidate_counts = [21, 21, 22]
#   extra_neighbors = 2
#   displacement = (-18.64135110937673, 0.0)
#   frame_speed = 74.56540443750691
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=36 mean=0.0510 max=0.2802 ref_px=250.0
#   [merge-9grid] frame=36 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=135.0000, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(21, 22), 有效元素=462, max=-0.0095, min=-27.6310
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=293.2371, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 23), 有效元素=506, max=-0.0013, min=-26.3431
#
# --- Window HMM Frame 37 ---
#   window_length = 3/3
#   candidate_counts = [21, 22, 23]
#   extra_neighbors = 3
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=37 mean=0.0879 max=0.2787 ref_px=250.0
#   [merge-9grid] frame=37 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=23 extra_candidates=3 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=293.2371, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 23), 有效元素=506, max=-0.0013, min=-26.3431
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=384.4802, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(23, 23), 有效元素=529, max=-0.0008, min=-15.5112
#
# --- Window HMM Frame 38 ---
#   window_length = 3/3
#   candidate_counts = [22, 23, 23]
#   extra_neighbors = 3
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=38 mean=0.0704 max=0.2773 ref_px=250.0
#   [merge-9grid] frame=38 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=23 extra_candidates=3 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=384.4802, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(23, 23), 有效元素=529, max=-0.0008, min=-15.5112
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=288.1406, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(23, 22), 有效元素=506, max=-0.0021, min=-26.9109
#
# --- Window HMM Frame 39 ---
#   window_length = 3/3
#   candidate_counts = [23, 23, 22]
#   extra_neighbors = 2
#   displacement = (-18.64135110937673, 0.0)
#   frame_speed = 74.56540443750691
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=39 mean=0.0751 max=0.2756 ref_px=250.0
#   [merge-9grid] frame=39 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=288.1406, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(23, 22), 有效元素=506, max=-0.0021, min=-26.9109
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=384.4802, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 24), 有效元素=528, max=-0.0008, min=-14.9170
#
# --- Window HMM Frame 40 ---
#   window_length = 3/3
#   candidate_counts = [23, 22, 24]
#   extra_neighbors = 4
#   displacement = (-14.913080889996763, 0.0)
#   frame_speed = 59.65232355998705
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=40 mean=0.0887 max=0.2839 ref_px=250.0
#   [merge-9grid] frame=40 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=24 extra_candidates=4 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691911 2740.        ], motion_radius=14.9131, radius=29.8, sigma=384.4802, displacement=(-14.913080889996763, 0.0), frame_speed=59.65232355998705
#     [transition] log_trans: shape=(22, 24), 有效元素=528, max=-0.0008, min=-14.9170
#     [transition] prev_best_global=193, center=[1825.08691912 2744.51008983], motion_radius=15.5801, radius=31.2, sigma=424.5292, displacement=(-14.91308088375854, 4.51008982680105), frame_speed=62.320576594423606
#     [transition] log_trans: shape=(24, 25), 有效元素=600, max=-0.0007, min=-12.2879
#
# --- Window HMM Frame 41 ---
#   window_length = 3/3
#   candidate_counts = [22, 24, 25]
#   extra_neighbors = 5
#   displacement = (-14.91308088375854, 4.51008982680105)
#   frame_speed = 62.320576594423606
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 172, 192]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=41 mean=0.1059 max=0.2855 ref_px=250.0
#   [merge-9grid] frame=41 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=25 extra_candidates=5 window_length=3
#     [transition] prev_best_global=193, center=[1825.08691912 2744.51008983], motion_radius=15.5801, radius=31.2, sigma=424.5292, displacement=(-14.91308088375854, 4.51008982680105), frame_speed=62.320576594423606
#     [transition] log_trans: shape=(24, 25), 有效元素=600, max=-0.0007, min=-12.2879
#     [transition] prev_best_global=193, center=[1821.35864888 2740.        ], motion_radius=18.6414, radius=37.3, sigma=443.1986, displacement=(-18.641351115614953, 0.0), frame_speed=74.56540446245981
#     [transition] log_trans: shape=(25, 26), 有效元素=650, max=-0.0009, min=-13.9333
#
# --- Window HMM Frame 42 ---
#   window_length = 3/3
#   candidate_counts = [24, 25, 26]
#   extra_neighbors = 6
#   displacement = (-18.641351115614953, 0.0)
#   frame_speed = 74.56540446245981
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=42 mean=0.1073 max=0.3256 ref_px=250.0
#   [merge-9grid] frame=42 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=26 extra_candidates=6 window_length=3
#     [transition] prev_best_global=151, center=[1821.35864888 2440.        ], motion_radius=18.6414, radius=37.3, sigma=443.1986, displacement=(-18.641351115614953, 0.0), frame_speed=74.56540446245981
#     [transition] log_trans: shape=(25, 26), 有效元素=650, max=-0.0009, min=-10.9551
#     [transition] prev_best_global=151, center=[1821.35864889 2440.        ], motion_radius=18.6414, radius=37.3, sigma=419.7043, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(26, 24), 有效元素=624, max=-0.0010, min=-12.2159
#
# --- Window HMM Frame 43 ---
#   window_length = 3/3
#   candidate_counts = [25, 26, 24]
#   extra_neighbors = 4
#   displacement = (-18.64135110937673, 0.0)
#   frame_speed = 74.56540443750691
#   predicted_center = None
#   Window HMM 输出 top-1 = 151, top-3 = [151, 172, 193]
#   best_path = [151, 151, 151]
#   [soft-penalty] frame=43 mean=0.0947 max=0.3236 ref_px=250.0
#   [merge-9grid] frame=43 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=24 extra_candidates=4 window_length=3
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=419.7043, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(26, 24), 有效元素=624, max=-0.0010, min=-15.5369
#     [transition] prev_best_global=193, center=[1828.81518933 2744.5100893 ], motion_radius=12.0599, radius=24.1, sigma=308.4346, displacement=(-11.184810670616798, 4.510089301223616), frame_speed=48.239551447757904
#     [transition] log_trans: shape=(24, 28), 有效元素=672, max=-0.0008, min=-24.1973
#
# --- Window HMM Frame 44 ---
#   window_length = 3/3
#   candidate_counts = [26, 24, 28]
#   extra_neighbors = 8
#   displacement = (-11.184810670616798, 4.510089301223616)
#   frame_speed = 48.239551447757904
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=44 mean=0.0794 max=0.2882 ref_px=250.0
#   [merge-9grid] frame=44 base_candidates=20 prev_top1=151 nine_grid=9 union_candidates=28 extra_candidates=8 window_length=3
#     [transition] prev_best_global=193, center=[1828.81518933 2744.5100893 ], motion_radius=12.0599, radius=24.1, sigma=308.4346, displacement=(-11.184810670616798, 4.510089301223616), frame_speed=48.239551447757904
#     [transition] log_trans: shape=(24, 28), 有效元素=672, max=-0.0008, min=-24.1973
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=225.0000, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(28, 22), 有效元素=616, max=-0.0034, min=-27.6310
#
# --- Window HMM Frame 45 ---
#   window_length = 3/3
#   candidate_counts = [24, 28, 22]
#   extra_neighbors = 2
#   displacement = (-18.64135110937673, 0.0)
#   frame_speed = 74.56540443750691
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 214]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=45 mean=0.0572 max=0.3219 ref_px=250.0
#   [merge-9grid] frame=45 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=22 extra_candidates=2 window_length=3
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=225.0000, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(28, 22), 有效元素=616, max=-0.0034, min=-27.6310
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=425.7183, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(22, 28), 有效元素=616, max=-0.0010, min=-15.1010
#
# --- Window HMM Frame 46 ---
#   window_length = 3/3
#   candidate_counts = [28, 22, 28]
#   extra_neighbors = 8
#   displacement = (-18.64135110937673, 0.0)
#   frame_speed = 74.56540443750691
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 172]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=46 mean=0.1369 max=0.3200 ref_px=250.0
#   [merge-9grid] frame=46 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=28 extra_candidates=8 window_length=3
#     [transition] prev_best_global=193, center=[1821.35864889 2740.        ], motion_radius=18.6414, radius=37.3, sigma=425.7183, displacement=(-18.64135110937673, 0.0), frame_speed=74.56540443750691
#     [transition] log_trans: shape=(22, 28), 有效元素=616, max=-0.0010, min=-15.1010
#     [transition] prev_best_global=193, center=[1828.81518933 2744.51008876], motion_radius=12.0599, radius=24.1, sigma=495.0000, displacement=(-11.184810670616798, 4.51008875537309), frame_speed=48.23955063122146
#     [transition] log_trans: shape=(28, 28), 有效元素=784, max=-0.0003, min=-11.2399
#
# --- Window HMM Frame 47 ---
#   window_length = 3/3
#   candidate_counts = [22, 28, 28]
#   extra_neighbors = 8
#   displacement = (-11.184810670616798, 4.51008875537309)
#   frame_speed = 48.23955063122146
#   predicted_center = None
#   Window HMM 输出 top-1 = 193, top-3 = [193, 192, 191]
#   best_path = [193, 193, 193]
#   [soft-penalty] frame=47 mean=0.1299 max=0.3202 ref_px=250.0
#   [merge-9grid] frame=47 base_candidates=20 prev_top1=193 nine_grid=9 union_candidates=28 extra_candidates=8 window_length=3
#     [transition] prev_best_global=193, center=[1828.81518933 2744.51008876], motion_radius=12.0599, radius=24.1, sigma=495.0000, displacement=(-11.184810670616798, 4.51008875537309), frame_speed=48.23955063122146
#     [transition] log_trans: shape=(28, 28), 有效元素=784, max=-0.0003, min=-11.2399
#     [transition] prev_best_global=193, center=[1821.35864888 2740.        ], motion_radius=18.6414, radius=37.3, sigma=443.1986, displacement=(-18.64135111561518, 0.0), frame_speed=74.56540446246072
#     [transition] log_trans: shape=(28, 26), 有效元素=728, max=-0.0009, min=-13.9333
#
# --- Window HMM Frame 48 ---
#   window_length = 3/3
#   candidate_counts = [28, 28, 26]
#   extra_neighbors = 6
#   displacement = (-18.64135111561518, 0.0)
# ...
#
# --- Window HMM Frame 415 ---
#   window_length = 3/3
#   candidate_counts = [23, 25, 25]
#   extra_neighbors = 5
#   displacement = (-3.7282702256184166, 18.040450422261983)
#   frame_speed = 73.68667182749677
#   predicted_center = None
#   Window HMM 输出 top-1 = 157, top-3 = [157, 178, 158]
#   best_path = [157, 157, 157]
#   [soft-penalty] frame=415 mean=0.0278 max=0.3674 ref_px=250.0
#   [merge-9grid] frame=415 base_candidates=20 prev_top1=158 nine_grid=9 union_candidates=25 extra_candidates=5 window_length=3
#     [transition] prev_best_global=179, center=[2736.27172977 2608.04045042], motion_radius=18.4217, radius=36.8, sigma=162.2498, displacement=(-3.7282702256184166, 18.040450422261983), frame_speed=73.68667182749677
#     [transition] log_trans: shape=(25, 25), 有效元素=625, max=-0.0064, min=-27.6310
#     [transition] prev_best_global=179, center=[2732.54345956 2603.5303322 ], motion_radius=15.4489, radius=30.9, sigma=142.3025, displacement=(-7.456540444998154, 13.53033219715735), frame_speed=61.7957778199548
#     [transition] log_trans: shape=(25, 25), 有效元素=625, max=-0.0059, min=-27.6310
#
# --- Window HMM Frame 416 ---
#   window_length = 3/3
#   candidate_counts = [25, 25, 25]
#   extra_neighbors = 5
#   displacement = (-7.456540444998154, 13.53033219715735)
#   frame_speed = 61.7957778199548
#   predicted_center = None
#   Window HMM 输出 top-1 = 179, top-3 = [179, 178, 158]
#   best_path = [179, 179, 179]
#   [soft-penalty] frame=416 mean=0.0190 max=0.1403 ref_px=250.0
#   [merge-9grid] frame=416 base_candidates=20 prev_top1=157 nine_grid=9 union_candidates=25 extra_candidates=5 window_length=3
#     [transition] prev_best_global=179, center=[2732.54345956 2603.5303322 ], motion_radius=15.4489, radius=30.9, sigma=142.3025, displacement=(-7.456540444998154, 13.53033219715735), frame_speed=61.7957778199548
#     [transition] log_trans: shape=(25, 25), 有效元素=625, max=-0.0059, min=-27.6310
#     [transition] prev_best_global=179, center=[2740.         2603.53032736], motion_radius=13.5303, radius=27.1, sigma=142.3025, displacement=(0.0, 13.530327364033838), frame_speed=54.12130945613535
#     [transition] log_trans: shape=(25, 29), 有效元素=725, max=-0.0045, min=-27.6310
#
# --- Window HMM Frame 417 ---
#   window_length = 3/3
#   candidate_counts = [25, 25, 29]
#   extra_neighbors = 9
#   displacement = (0.0, 13.530327364033838)
#   frame_speed = 54.12130945613535
#   predicted_center = None
#   Window HMM 输出 top-1 = 179, top-3 = [179, 200, 178]
#   best_path = [179, 179, 179]
#   [soft-penalty] frame=417 mean=0.0375 max=0.2083 ref_px=250.0
#   [merge-9grid] frame=417 base_candidates=20 prev_top1=179 nine_grid=9 union_candidates=29 extra_candidates=9 window_length=3
#     [transition] prev_best_global=153, center=[2140.         2453.53032736], motion_radius=13.5303, radius=27.1, sigma=142.3025, displacement=(0.0, 13.530327364033838), frame_speed=54.12130945613535
#     [transition] log_trans: shape=(25, 29), 有效元素=725, max=-0.0045, min=-27.6310
#     [transition] prev_best_global=153, center=[2132.54345956 2458.04042899], motion_radius=19.5207, radius=39.0, sigma=185.5398, displacement=(-7.456540438760385, 18.040428993699607), frame_speed=78.08273290213003
#     [transition] log_trans: shape=(29, 27), 有效元素=783, max=-0.0055, min=-27.6309
#
# --- Window HMM Frame 418 ---
#   window_length = 3/3
#   candidate_counts = [25, 29, 27]
#   extra_neighbors = 7
#   displacement = (-7.456540438760385, 18.040428993699607)
#   frame_speed = 78.08273290213003
#   predicted_center = None
#   Window HMM 输出 top-1 = 153, top-3 = [153, 174, 155]
#   best_path = [153, 153, 153]
#   [soft-penalty] frame=418 mean=0.0352 max=0.1768 ref_px=250.0
#   [merge-9grid] frame=418 base_candidates=20 prev_top1=179 nine_grid=9 union_candidates=27 extra_candidates=7 window_length=3
#     [transition] prev_best_global=153, center=[2132.54345956 2458.04042899], motion_radius=19.5207, radius=39.0, sigma=185.5398, displacement=(-7.456540438760385, 18.040428993699607), frame_speed=78.08273290213003
#     [transition] log_trans: shape=(29, 27), 有效元素=783, max=-0.0055, min=-27.6309
#     [transition] prev_best_global=153, center=[2136.27172977 2458.04042041], motion_radius=18.4216, radius=36.8, sigma=225.0000, displacement=(-3.728270225617962, 18.04042040511922), frame_speed=73.68655424362535
#     [transition] log_trans: shape=(27, 23), 有效元素=621, max=-0.0034, min=-27.5997
#
# --- Window HMM Frame 419 ---
#   window_length = 3/3
#   candidate_counts = [29, 27, 23]
#   extra_neighbors = 3
#   displacement = (-3.728270225617962, 18.04042040511922)
#   frame_speed = 73.68655424362535
#   predicted_center = None
#   Window HMM 输出 top-1 = 153, top-3 = [153, 174, 155]
#   best_path = [153, 153, 153]
#   [soft-penalty] frame=419 mean=0.0586 max=0.2151 ref_px=250.0
#   [merge-9grid] frame=419 base_candidates=20 prev_top1=153 nine_grid=9 union_candidates=23 extra_candidates=3 window_length=3
#     [transition] prev_best_global=174, center=[2136.27172977 2608.04042041], motion_radius=18.4216, radius=36.8, sigma=225.0000, displacement=(-3.728270225617962, 18.04042040511922), frame_speed=73.68655424362535
#     [transition] log_trans: shape=(27, 23), 有效元素=621, max=-0.0034, min=-27.6308
#     [transition] prev_best_global=174, center=[2140.         2603.53030969], motion_radius=13.5303, radius=27.1, sigma=185.5398, displacement=(0.0, 13.530309694047446), frame_speed=54.121238776189784
#     [transition] log_trans: shape=(23, 23), 有效元素=529, max=-0.0027, min=-27.6308
#
# --- Window HMM Frame 420 ---
#   window_length = 3/3
#   candidate_counts = [27, 23, 23]
#   extra_neighbors = 3
#   displacement = (0.0, 13.530309694047446)
#   frame_speed = 54.121238776189784
#   predicted_center = None
#   Window HMM 输出 top-1 = 174, top-3 = [174, 175, 195]
#   best_path = [174, 174, 174]
#   [soft-penalty] frame=420 mean=0.0372 max=0.1525 ref_px=250.0
#   [merge-9grid] frame=420 base_candidates=20 prev_top1=153 nine_grid=9 union_candidates=23 extra_candidates=3 window_length=3
#     [transition] prev_best_global=175, center=[2290.         2603.53030969], motion_radius=13.5303, radius=27.1, sigma=185.5398, displacement=(0.0, 13.530309694047446), frame_speed=54.121238776189784
#     [transition] log_trans: shape=(23, 23), 有效元素=529, max=-0.0027, min=-27.6301
#     [transition] prev_best_global=175, center=[2286.27172977 2603.53030486], motion_radius=14.0346, radius=28.1, sigma=162.2498, displacement=(-3.7282702256184166, 13.530304857805277), frame_speed=56.13827905027112
#     [transition] log_trans: shape=(23, 21), 有效元素=483, max=-0.0037, min=-27.6310
#
# --- Window HMM Frame 421 ---
#   window_length = 3/3
#   candidate_counts = [23, 23, 21]
#   extra_neighbors = 1
#   displacement = (-3.7282702256184166, 13.530304857805277)
#   frame_speed = 56.13827905027112
#   predicted_center = None
#   Window HMM 输出 top-1 = 175, top-3 = [175, 196, 174]
#   best_path = [175, 175, 175]
#   [soft-penalty] frame=421 mean=0.0372 max=0.1552 ref_px=250.0
#   [merge-9grid] frame=421 base_candidates=20 prev_top1=174 nine_grid=9 union_candidates=21 extra_candidates=1 window_length=3
#     [transition] prev_best_global=196, center=[2286.27172977 2753.53030486], motion_radius=14.0346, radius=28.1, sigma=162.2498, displacement=(-3.7282702256184166, 13.530304857805277), frame_speed=56.13827905027112
#     [transition] log_trans: shape=(23, 21), 有效元素=483, max=-0.0037, min=-27.6310
#     [transition] prev_best_global=196, center=[2286.27172977 2758.04039898], motion_radius=18.4216, radius=36.8, sigma=225.0000, displacement=(-3.7282702256184166, 18.040398982794613), frame_speed=73.68647032758724
#     [transition] log_trans: shape=(21, 24), 有效元素=504, max=-0.0034, min=-27.2474
#
# --- Window HMM Frame 422 ---
#   window_length = 3/3
#   candidate_counts = [23, 21, 24]
#   extra_neighbors = 4
#   displacement = (-3.7282702256184166, 18.040398982794613)
#   frame_speed = 73.68647032758724
#   predicted_center = None
#   Window HMM 输出 top-1 = 196, top-3 = [196, 195, 175]
#   best_path = [196, 196, 196]
#   [soft-penalty] frame=422 mean=0.0409 max=0.1588 ref_px=250.0
#   [merge-9grid] frame=422 base_candidates=20 prev_top1=175 nine_grid=9 union_candidates=24 extra_candidates=4 window_length=3
#     [transition] prev_best_global=196, center=[2286.27172977 2758.04039898], motion_radius=18.4216, radius=36.8, sigma=225.0000, displacement=(-3.7282702256184166, 18.040398982794613), frame_speed=73.68647032758724
#     [transition] log_trans: shape=(21, 24), 有效元素=504, max=-0.0034, min=-27.2474
#     [transition] prev_best_global=196, center=[2286.27172978 2758.04039041], motion_radius=18.4216, radius=36.8, sigma=279.1647, displacement=(-3.7282702193801924, 18.040390411370026), frame_speed=73.68643674635042
#     [transition] log_trans: shape=(24, 26), 有效元素=624, max=-0.0022, min=-27.5418
#
# --- Window HMM Frame 423 ---
#   window_length = 3/3
#   candidate_counts = [21, 24, 26]
#   extra_neighbors = 6
#   displacement = (-3.7282702193801924, 18.040390411370026)
#   frame_speed = 73.68643674635042
#   predicted_center = None
#   Window HMM 输出 top-1 = 196, top-3 = [196, 175, 195]
#   best_path = [196, 196, 196]
#   [soft-penalty] frame=423 mean=0.0738 max=0.3249 ref_px=250.0
#   [merge-9grid] frame=423 base_candidates=20 prev_top1=196 nine_grid=9 union_candidates=26 extra_candidates=6 window_length=3
#     [transition] prev_best_global=200, center=[2736.27172978 2758.04039041], motion_radius=18.4216, radius=36.8, sigma=279.1647, displacement=(-3.7282702193801924, 18.040390411370026), frame_speed=73.68643674635042
#     [transition] log_trans: shape=(24, 26), 有效元素=624, max=-0.1394, min=-27.6309
#     [transition] prev_best_global=199, center=[2590.         2753.53028718], motion_radius=13.5303, radius=27.1, sigma=288.1406, displacement=(0.0, 13.530287175341982), frame_speed=54.12114870136793
#     [transition] log_trans: shape=(26, 26), 有效元素=676, max=-0.0011, min=-11.0368
#
# --- Window HMM Frame 424 ---
#   window_length = 3/3
#   candidate_counts = [24, 26, 26]
#   extra_neighbors = 6
#   displacement = (0.0, 13.530287175341982)
#   frame_speed = 54.12114870136793
#   predicted_center = None
#   Window HMM 输出 top-1 = 199, top-3 = [199, 197, 179]
#   best_path = [200, 199, 199]
#   [soft-penalty] frame=424 mean=0.0390 max=0.1070 ref_px=250.0
#   [merge-9grid] frame=424 base_candidates=20 prev_top1=196 nine_grid=9 union_candidates=26 extra_candidates=6 window_length=3
#     [transition] prev_best_global=174, center=[2140.         2603.53028718], motion_radius=13.5303, radius=27.1, sigma=288.1406, displacement=(0.0, 13.530287175341982), frame_speed=54.12114870136793
#     [transition] log_trans: shape=(26, 26), 有效元素=676, max=-0.0011, min=-13.4513
#     [transition] prev_best_global=174, center=[2136.27172978 2608.04037541], motion_radius=18.4216, radius=36.8, sigma=229.4559, displacement=(-3.7282702193797377, 18.04037540669742), frame_speed=73.68637796969391
#     [transition] log_trans: shape=(26, 24), 有效元素=624, max=-0.0032, min=-21.8426
#
# --- Window HMM Frame 425 ---
#   window_length = 3/3
#   candidate_counts = [26, 26, 24]
#   extra_neighbors = 4
#   displacement = (-3.7282702193797377, 18.04037540669742)
#   frame_speed = 73.68637796969391
#   predicted_center = None
#   Window HMM 输出 top-1 = 174, top-3 = [174, 173, 194]
#   best_path = [174, 174, 174]
#   [soft-penalty] frame=425 mean=0.0410 max=0.1242 ref_px=250.0
#   [merge-9grid] frame=425 base_candidates=20 prev_top1=199 nine_grid=9 union_candidates=24 extra_candidates=4 window_length=3
#     [transition] prev_best_global=199, center=[2586.27172978 2758.04037541], motion_radius=18.4216, radius=36.8, sigma=229.4559, displacement=(-3.7282702193797377, 18.04037540669742), frame_speed=73.68637796969391
#     [transition] log_trans: shape=(26, 24), 有效元素=624, max=-0.0032, min=-19.7281
#     [transition] prev_best_global=199, center=[2590.         2749.02018449], motion_radius=9.0202, radius=18.0, sigma=286.3728, displacement=(0.0, 9.020184491404052), frame_speed=36.08073796561621
#     [transition] log_trans: shape=(24, 28), 有效元素=672, max=-0.2914, min=-23.5190
#
# --- Window HMM Frame 426 ---
#   window_length = 3/3
#   candidate_counts = [26, 24, 28]
#   extra_neighbors = 8
#   displacement = (0.0, 9.020184491404052)
#   frame_speed = 36.08073796561621
#   predicted_center = None
#   Window HMM 输出 top-1 = 177, top-3 = [177, 201, 196]
#   best_path = [199, 199, 177]
#   [soft-penalty] frame=426 mean=0.0712 max=0.2404 ref_px=250.0
#   [merge-9grid] frame=426 base_candidates=20 prev_top1=174 nine_grid=9 union_candidates=28 extra_candidates=8 window_length=3
#     [transition] prev_best_global=201, center=[2890.         2749.02018449], motion_radius=9.0202, radius=18.0, sigma=286.3728, displacement=(0.0, 9.020184491404052), frame_speed=36.08073796561621
#     [transition] log_trans: shape=(24, 28), 有效元素=672, max=-0.0005, min=-24.9104
#     [transition] prev_best_global=201, center=[2890.         2744.51009143], motion_radius=4.5101, radius=9.0, sigma=284.6050, displacement=(0.0, 4.510091433163325), frame_speed=18.0403657326533
#     [transition] log_trans: shape=(28, 29), 有效元素=812, max=-0.5557, min=-27.3064
#
# --- Window HMM Frame 427 ---
#   window_length = 3/3
#   candidate_counts = [24, 28, 29]
#   extra_neighbors = 9
#   displacement = (0.0, 4.510091433163325)
#   frame_speed = 18.0403657326533
#   predicted_center = None
#   Window HMM 输出 top-1 = 199, top-3 = [199, 158, 178]
#   best_path = [201, 201, 199]
#   [soft-penalty] frame=427 mean=0.0643 max=0.2808 ref_px=250.0
#   [merge-9grid] frame=427 base_candidates=20 prev_top1=177 nine_grid=9 union_candidates=29 extra_candidates=9 window_length=3
#     [transition] prev_best_global=201, center=[2890.         2744.51009143], motion_radius=4.5101, radius=9.0, sigma=284.6050, displacement=(0.0, 4.510091433163325), frame_speed=18.0403657326533
#     [transition] log_trans: shape=(28, 29), 有效元素=812, max=-0.5557, min=-27.3064
#     [transition] prev_best_global=199, center=[2590.         2744.51009091], motion_radius=4.5101, radius=9.0, sigma=254.5584, displacement=(0.0, 4.510090910705458), frame_speed=18.04036364282183
#     [transition] log_trans: shape=(29, 29), 有效元素=841, max=-0.0002, min=-27.6298
#
# --- Window HMM Frame 428 ---
#   window_length = 3/3
#   candidate_counts = [28, 29, 29]
#   extra_neighbors = 9
#   displacement = (0.0, 4.510090910705458)
#   frame_speed = 18.04036364282183
#   predicted_center = None
#   Window HMM 输出 top-1 = 199, top-3 = [199, 219, 200]
#   best_path = [201, 199, 199]
#   [soft-penalty] frame=428 mean=0.0655 max=0.2820 ref_px=250.0
#   [merge-9grid] frame=428 base_candidates=20 prev_top1=199 nine_grid=9 union_candidates=29 extra_candidates=9 window_length=3
# [city2] 真实帧间像素位移统计: mean=13.71px  median=14.04px  p90=15.58px  max=19.52px  expansion_radius=25.26px  (n=327)
# [city3] 真实帧间像素位移统计: mean=16.42px  median=15.58px  p90=19.18px  max=22.54px  expansion_radius=28.04px  (n=361)
# [industry1] 真实帧间像素位移统计: mean=16.76px  median=17.43px  p90=19.18px  max=22.54px  expansion_radius=31.37px  (n=474)
# [industry2] 真实帧间像素位移统计: mean=16.30px  median=15.58px  p90=19.18px  max=21.20px  expansion_radius=28.04px  (n=261)
# [industry3] 真实帧间像素位移统计: mean=16.54px  median=15.58px  p90=19.18px  max=22.51px  expansion_radius=28.04px  (n=623)
# [park1] 真实帧间像素位移统计: mean=10.89px  median=11.18px  p90=14.04px  max=15.58px  expansion_radius=24.00px  (n=397)
# [rural1] 真实帧间像素位移统计: mean=10.92px  median=11.18px  p90=13.51px  max=15.58px  expansion_radius=24.00px  (n=243)
# [rural2] 真实帧间像素位移统计: mean=13.60px  median=13.51px  p90=15.58px  max=18.39px  expansion_radius=24.32px  (n=417)
# [rural3] 真实帧间像素位移统计: mean=16.01px  median=15.58px  p90=19.18px  max=21.20px  expansion_radius=28.04px  (n=428)
# [school] 真实帧间像素位移统计: mean=16.26px  median=15.58px  p90=18.64px  max=20.70px  expansion_radius=28.04px  (n=532)
# [suburbs1] 真实帧间像素位移统计: mean=35.37px  median=40.34px  p90=40.68px  max=48.84px  expansion_radius=72.61px  (n=226)
# [suburbs2] 真实帧间像素位移统计: mean=16.02px  median=15.58px  p90=18.64px  max=20.70px  expansion_radius=28.04px  (n=487)
# [village1] 真实帧间像素位移统计: mean=17.12px  median=18.01px  p90=19.49px  max=23.02px  expansion_radius=32.41px  (n=309)
# [village2] 真实帧间像素位移统计: mean=16.09px  median=15.58px  p90=19.18px  max=21.20px  expansion_radius=28.04px  (n=460)
# Top1 融合统计: 使用 HMM top1 0 次, 回退到 HNSW top1 0 次, 融合启用=False, HNSW topN=5

# %%
valid = np.array([len(gt_9_list[i]) > 0 for i in range(n_queries)])
n_eval = int(np.sum(valid))

topk_eval_5 = min(5, topk_hnsw.shape[1])
topk_eval_10 = min(10, topk_hnsw.shape[1])
topk_eval_20 = min(20, topk_hnsw.shape[1])

# Recall@1 / @5 / @10 / @20：top-k 中是否有任一张在 GT（方圆 25 张）内
correct_1_hnsw = np.array([topk_hnsw[i, 0] in gt_9_list[i] if topk_hnsw[i, 0] >= 0 else False for i in range(n_queries)])
correct_5_hnsw = np.array([any(topk_hnsw[i, j] in gt_9_list[i] for j in range(topk_eval_5)) for i in range(n_queries)])
correct_10_hnsw = np.array([any(topk_hnsw[i, j] in gt_9_list[i] for j in range(topk_eval_10)) for i in range(n_queries)])
correct_20_hnsw = np.array([any(topk_hnsw[i, j] in gt_9_list[i] for j in range(topk_eval_20)) for i in range(n_queries)])
correct_1_hmm = np.array([pred_hmm[i] in gt_9_list[i] for i in range(n_queries)])
correct_5_hmm = np.array([any(topk_hmm[i, j] in gt_9_list[i] for j in range(topk_eval_5)) for i in range(n_queries)])
correct_10_hmm = np.array([any(topk_hmm[i, j] in gt_9_list[i] for j in range(topk_eval_10)) for i in range(n_queries)])
correct_20_hmm = np.array([any(topk_hmm[i, j] in gt_9_list[i] for j in range(topk_eval_20)) for i in range(n_queries)])

center_gt_idx = np.full(n_queries, -1, dtype=np.int64)
for i in range(n_queries):
    if i < len(gt_25_ordered) and gt_25_ordered[i]:
        center_gt_idx[i] = int(gt_25_ordered[i][0])
    elif len(gt_9_list[i]) > 0:
        center_gt_idx[i] = int(min(gt_9_list[i]))

center_acc_hnsw = np.array([
    topk_hnsw[i, 0] == center_gt_idx[i] if center_gt_idx[i] >= 0 and topk_hnsw[i, 0] >= 0 else False
    for i in range(n_queries)
])
center_acc_hmm = np.array([
    pred_hmm[i] == center_gt_idx[i] if center_gt_idx[i] >= 0 and pred_hmm[i] >= 0 else False
    for i in range(n_queries)
])

query_coords_valid = np.isfinite(query_px_all) & np.isfinite(query_py_all)

def _top1_localization_errors(pred_indices):
    errors = np.full(n_queries, np.nan, dtype=np.float64)
    for i in range(n_queries):
        pred_idx = int(pred_indices[i])
        if pred_idx < 0 or pred_idx >= len(database_coords):
            continue
        if not query_coords_valid[i]:
            continue
        pred_coord = database_coords[pred_idx]
        if np.any(np.isnan(pred_coord)):
            continue
        errors[i] = float(np.hypot(pred_coord[0] - query_px_all[i], pred_coord[1] - query_py_all[i]))
    return errors

loc_error_hnsw = _top1_localization_errors(topk_hnsw[:, 0])
loc_error_hmm = _top1_localization_errors(pred_hmm)

# 诊断：query 与预测分别属于哪个场景（全局检索时预测常落在其它场景导致 Recall=0）
query_to_scene = {}
for scene_name, start, end in trajectory_ranges:
    for i in range(start, end):
        query_to_scene[i] = scene_name
db_idx_to_scene = {}
for scene_name, start, end in db_scene_ranges:
    for j in range(start, end):
        db_idx_to_scene[j] = scene_name
valid_indices = np.where(valid)[0]
n_diag = min(5, len(valid_indices))
print("诊断（前 %d 条有 GT 的 query）：" % n_diag)
for k in range(n_diag):
    i = valid_indices[k]
    q_scene = query_to_scene.get(i, "?")
    p_hnsw = int(pred_hnsw[i])
    p_hmm = int(pred_hmm[i])
    p_hnsw_scene = db_idx_to_scene.get(p_hnsw, "?")
    p_hmm_scene = db_idx_to_scene.get(p_hmm, "?")
    gt_set = (gt_25_ordered[i][:5] if i < len(gt_25_ordered) and gt_25_ordered[i] else list(gt_9_list[i])[:5])
    in_hnsw = correct_1_hnsw[i]
    in_hmm = correct_1_hmm[i]
    print(f"  query {i}: 场景={q_scene} | HNSW pred={p_hnsw} (场景={p_hnsw_scene}) in_GT={in_hnsw} | HMM pred={p_hmm} (场景={p_hmm_scene}) in_GT={in_hmm} | GT 示例={gt_set}")
same_scene_hnsw = sum(1 for i in valid_indices if query_to_scene.get(i) == db_idx_to_scene.get(pred_hnsw[i]))
same_scene_hmm = sum(1 for i in valid_indices if query_to_scene.get(i) == db_idx_to_scene.get(pred_hmm[i]))
print(f"预测与 query 同场景的比例: HNSW {same_scene_hnsw}/{n_eval}, HMM {same_scene_hmm}/{n_eval}")
i0 = valid_indices[0]
p0 = int(pred_hnsw[i0])
gt0 = gt_25_ordered[i0] if (i0 < len(gt_25_ordered) and gt_25_ordered[i0]) else list(gt_9_list[i0])
print("")
print("query 0 细查（看预测与 GT 子图是否相邻）:")
print(f"  预测子图 db_names[{p0}] = {db_names[p0]}")
for g in sorted(gt0)[:5]:
    print(f"  GT 子图 db_names[{g}] = {db_names[g]}")
print("  （若 id_startx_starty 相差很大，说明坐标→瓦片或 query 与 uav_infos 行序可能不一致）")
print("前 3 条 query 的图像名（请与 uav_infos 前 3 行的 file_name 核对是否一一对应）:")
for k in range(min(3, len(query_names))):
    print(f"  query {k}: {query_names[k]}")
print("")

if n_eval > 0:
    r1_hnsw = correct_1_hnsw[valid].mean()
    r5_hnsw = correct_5_hnsw[valid].mean()
    r10_hnsw = correct_10_hnsw[valid].mean()
    r20_hnsw = correct_20_hnsw[valid].mean()
    r1_hmm = correct_1_hmm[valid].mean()
    r5_hmm = correct_5_hmm[valid].mean()
    r10_hmm = correct_10_hmm[valid].mean()
    r20_hmm = correct_20_hmm[valid].mean()
    center_valid = valid & (center_gt_idx >= 0)
    center_acc1_hnsw = center_acc_hnsw[center_valid].mean() if np.any(center_valid) else np.nan
    center_acc1_hmm = center_acc_hmm[center_valid].mean() if np.any(center_valid) else np.nan
    loc_valid_hnsw = valid & np.isfinite(loc_error_hnsw)
    loc_valid_hmm = valid & np.isfinite(loc_error_hmm)
    median_loc_hnsw = np.median(loc_error_hnsw[loc_valid_hnsw]) if np.any(loc_valid_hnsw) else np.nan
    median_loc_hmm = np.median(loc_error_hmm[loc_valid_hmm]) if np.any(loc_valid_hmm) else np.nan
    mean_loc_hnsw = np.mean(loc_error_hnsw[loc_valid_hnsw]) if np.any(loc_valid_hnsw) else np.nan
    mean_loc_hmm = np.mean(loc_error_hmm[loc_valid_hmm]) if np.any(loc_valid_hmm) else np.nan
    print("Recall（仅在有坐标法 GT 的 query 上，命中方圆 25 张即正确）:")
    print(f"  HNSW:        Recall@1={r1_hnsw:.4f}  Recall@5={r5_hnsw:.4f}  Recall@10={r10_hnsw:.4f}  Recall@20={r20_hnsw:.4f}  (n={n_eval})")
    print(f"  HNSW + HMM:  Recall@1={r1_hmm:.4f}  Recall@5={r5_hmm:.4f}  Recall@10={r10_hmm:.4f}  Recall@20={r20_hmm:.4f}")
    print("附加指标:")
    print(f"  HNSW:        Center-tile Accuracy@1={center_acc1_hnsw:.4f}  Median localization error={median_loc_hnsw:.2f}px  Mean localization error={mean_loc_hnsw:.2f}px")
    print(f"  HNSW + HMM:  Center-tile Accuracy@1={center_acc1_hmm:.4f}  Median localization error={median_loc_hmm:.2f}px  Mean localization error={mean_loc_hmm:.2f}px")
    print("")
    print("各场景 Recall（仅统计该场景中有坐标法 GT 的 query）:")
    for scene_name, start, end in trajectory_ranges:
        scene_indices = np.arange(start, end)
        scene_valid = valid[scene_indices]
        n_scene_eval = int(np.sum(scene_valid))
        if n_scene_eval == 0:
            print(f"  [{scene_name}] 无有效 GT，跳过")
            continue
        r1_hnsw_scene = correct_1_hnsw[scene_indices][scene_valid].mean()
        r5_hnsw_scene = correct_5_hnsw[scene_indices][scene_valid].mean()
        r10_hnsw_scene = correct_10_hnsw[scene_indices][scene_valid].mean()
        r20_hnsw_scene = correct_20_hnsw[scene_indices][scene_valid].mean()
        r1_hmm_scene = correct_1_hmm[scene_indices][scene_valid].mean()
        r5_hmm_scene = correct_5_hmm[scene_indices][scene_valid].mean()
        r10_hmm_scene = correct_10_hmm[scene_indices][scene_valid].mean()
        r20_hmm_scene = correct_20_hmm[scene_indices][scene_valid].mean()
        scene_center_valid = center_valid[scene_indices]
        scene_loc_valid_hnsw = loc_valid_hnsw[scene_indices]
        scene_loc_valid_hmm = loc_valid_hmm[scene_indices]
        center_hnsw_scene = center_acc_hnsw[scene_indices][scene_center_valid].mean() if np.any(scene_center_valid) else np.nan
        center_hmm_scene = center_acc_hmm[scene_indices][scene_center_valid].mean() if np.any(scene_center_valid) else np.nan
        median_loc_hnsw_scene = np.median(loc_error_hnsw[scene_indices][scene_loc_valid_hnsw]) if np.any(scene_loc_valid_hnsw) else np.nan
        median_loc_hmm_scene = np.median(loc_error_hmm[scene_indices][scene_loc_valid_hmm]) if np.any(scene_loc_valid_hmm) else np.nan
        print(f"  [{scene_name}] HNSW:       R@1={r1_hnsw_scene:.4f}  R@5={r5_hnsw_scene:.4f}  R@10={r10_hnsw_scene:.4f}  R@20={r20_hnsw_scene:.4f}  Center@1={center_hnsw_scene:.4f}  MedErr={median_loc_hnsw_scene:.2f}px  (n={n_scene_eval})")
        print(f"  [{scene_name}] HNSW+HMM:   R@1={r1_hmm_scene:.4f}  R@5={r5_hmm_scene:.4f}  R@10={r10_hmm_scene:.4f}  R@20={r20_hmm_scene:.4f}  Center@1={center_hmm_scene:.4f}  MedErr={median_loc_hmm_scene:.2f}px")
else:
    print("无有效坐标法 GT，请检查 uav_infos.csv 与 GDAL 路径。")

# 将 HNSW 与 HNSW+HMM 的 top-10 结果保存到 ch3/results（每行：查询图像名\t检索到的 db 图像名 x10）
results_dir = Path(_root) / "results"
results_dir.mkdir(parents=True, exist_ok=True)
def _name(i, names): return names[i] if 0 <= i < len(names) else "-"
with open(results_dir / "hnsw_top10.txt", "w", encoding="utf-8") as f:
    f.write("query\ttop1_correct\tdb_1\tdb_2\tdb_3\tdb_4\tdb_5\tdb_6\tdb_7\tdb_8\tdb_9\tdb_10\n")
    for i in range(n_queries):
        q = _name(i, query_names)
        db_cols = [_name(int(topk_hnsw[i, j]), db_names) for j in range(10)]
        top1_correct = "True" if correct_1_hnsw[i] else "False"
        f.write("\t".join([q, top1_correct] + db_cols) + "\n")
with open(results_dir / "hnsw_hmm_top10.txt", "w", encoding="utf-8") as f:
    f.write("query\ttop1_correct\tdb_1\tdb_2\tdb_3\tdb_4\tdb_5\tdb_6\tdb_7\tdb_8\tdb_9\tdb_10\n")
    for i in range(n_queries):
        q = _name(i, query_names)
        db_cols = [_name(int(topk_hmm[i, j]), db_names) for j in range(10)]
        top1_correct = "True" if correct_1_hmm[i] else "False"
        f.write("\t".join([q, top1_correct] + db_cols) + "\n")
with open(results_dir / "gt_25.txt", "w", encoding="utf-8") as f:
    f.write("query\t" + "\t".join(f"db_{j}" for j in range(1, 26)) + "\n")
    for i in range(n_queries):
        q = _name(i, query_names)
        gt_indices = gt_25_ordered[i][:25] if i < len(gt_25_ordered) and gt_25_ordered[i] else sorted(gt_9_list[i])[:25]
        db_cols = [_name(idx, db_names) for idx in gt_indices]
        db_cols += ["-"] * (25 - len(db_cols))
        f.write("\t".join([q] + db_cols) + "\n")
print(f"按场景检索 Top-10 已保存: {results_dir / 'hnsw_top10.txt'}, {results_dir / 'hnsw_hmm_top10.txt'}")
print(f"GT 已保存: {results_dir / 'gt_25.txt'}")
# Out:
# 诊断（前 5 条有 GT 的 query）：
#   query 0: 场景=city1 | HNSW pred=175 (场景=city1) in_GT=True | HMM pred=196 (场景=city1) in_GT=True | GT 示例=[196, 175, 195, 197, 174]
#   query 1: 场景=city1 | HNSW pred=175 (场景=city1) in_GT=True | HMM pred=196 (场景=city1) in_GT=True | GT 示例=[196, 175, 195, 174, 197]
#   query 2: 场景=city1 | HNSW pred=175 (场景=city1) in_GT=True | HMM pred=196 (场景=city1) in_GT=True | GT 示例=[196, 175, 195, 174, 197]
#   query 3: 场景=city1 | HNSW pred=175 (场景=city1) in_GT=True | HMM pred=196 (场景=city1) in_GT=True | GT 示例=[196, 195, 175, 174, 217]
#   query 4: 场景=city1 | HNSW pred=175 (场景=city1) in_GT=True | HMM pred=175 (场景=city1) in_GT=True | GT 示例=[196, 195, 175, 174, 217]
# 预测与 query 同场景的比例: HNSW 5988/5988, HMM 5988/5988
#
# query 0 细查（看预测与 GT 子图是否相邻）:
#   预测子图 db_names[175] = tif/259_1906_2206.tif
#   GT 子图 db_names[133] = tif/220_1756_1906.tif
#   GT 子图 db_names[134] = tif/221_1906_1906.tif
#   GT 子图 db_names[152] = tif/238_1606_2056.tif
#   GT 子图 db_names[153] = tif/239_1756_2056.tif
#   GT 子图 db_names[155] = tif/240_1906_2056.tif
#   （若 id_startx_starty 相差很大，说明坐标→瓦片或 query 与 uav_infos 行序可能不一致）
# 前 3 条 query 的图像名（请与 uav_infos 前 3 行的 file_name 核对是否一一对应）:
#   query 0: uav/001.jpg
#   query 1: uav/002.jpg
#   query 2: uav/003.jpg
#
# Recall（仅在有坐标法 GT 的 query 上，命中方圆 25 张即正确）:
#   HNSW:        Recall@1=0.7406  Recall@5=0.8858  Recall@10=0.9304  Recall@20=0.9641  (n=5988)
#   HNSW + HMM:  Recall@1=0.9457  Recall@5=0.9860  Recall@10=0.9910  Recall@20=0.9940
# 附加指标:
#   HNSW:        Center-tile Accuracy@1=0.1633  Median localization error=206.46px  Mean localization error=467.85px
#   HNSW + HMM:  Center-tile Accuracy@1=0.2213  Median localization error=156.75px  Mean localization error=183.89px
#
# 各场景 Recall（仅统计该场景中有坐标法 GT 的 query）:
#   [city1] HNSW:       R@1=0.8228  R@5=0.9184  R@10=0.9604  R@20=0.9837  Center@1=0.1515  MedErr=193.25px  (n=429)
#   [city1] HNSW+HMM:   R@1=0.9627  R@5=0.9907  R@10=0.9907  R@20=0.9977  Center@1=0.2051  MedErr=152.35px
#   [city2] HNSW:       R@1=0.9665  R@5=1.0000  R@10=1.0000  R@20=1.0000  Center@1=0.3293  MedErr=112.73px  (n=328)
#   [city2] HNSW+HMM:   R@1=0.9909  R@5=1.0000  R@10=1.0000  R@20=1.0000  Center@1=0.3628  MedErr=105.86px
#   [city3] HNSW:       R@1=0.8674  R@5=0.9724  R@10=0.9862  R@20=0.9972  Center@1=0.2182  MedErr=177.14px  (n=362)
#   [city3] HNSW+HMM:   R@1=0.9890  R@5=1.0000  R@10=1.0000  R@20=1.0000  Center@1=0.2818  MedErr=147.50px
#   [industry1] HNSW:       R@1=0.9347  R@5=0.9958  R@10=1.0000  R@20=1.0000  Center@1=0.2526  MedErr=136.19px  (n=475)
#   [industry1] HNSW+HMM:   R@1=0.9937  R@5=1.0000  R@10=1.0000  R@20=1.0000  Center@1=0.3011  MedErr=117.41px
#   [industry2] HNSW:       R@1=0.3397  R@5=0.5076  R@10=0.6374  R@20=0.8015  Center@1=0.0229  MedErr=1024.63px  (n=262)
#   [industry2] HNSW+HMM:   R@1=0.8550  R@5=0.9351  R@10=0.9542  R@20=0.9809  Center@1=0.1069  MedErr=228.84px
#   [industry3] HNSW:       R@1=0.7260  R@5=0.8622  R@10=0.9247  R@20=0.9583  Center@1=0.1907  MedErr=190.63px  (n=624)
#   [industry3] HNSW+HMM:   R@1=0.9407  R@5=0.9904  R@10=0.9936  R@20=0.9952  Center@1=0.2388  MedErr=148.18px
#   [park1] HNSW:       R@1=0.8492  R@5=0.9698  R@10=0.9925  R@20=1.0000  Center@1=0.1658  MedErr=172.22px  (n=398)
#   [park1] HNSW+HMM:   R@1=0.9925  R@5=1.0000  R@10=1.0000  R@20=1.0000  Center@1=0.2261  MedErr=144.64px
#   [rural1] HNSW:       R@1=0.4508  R@5=0.7582  R@10=0.8443  R@20=0.9180  Center@1=0.1148  MedErr=457.22px  (n=244)
#   [rural1] HNSW+HMM:   R@1=0.8893  R@5=0.9713  R@10=0.9836  R@20=0.9877  Center@1=0.2254  MedErr=153.19px
#   [rural2] HNSW:       R@1=0.5981  R@5=0.7177  R@10=0.7871  R@20=0.8589  Center@1=0.0359  MedErr=330.37px  (n=418)
#   [rural2] HNSW+HMM:   R@1=0.8589  R@5=0.9450  R@10=0.9641  R@20=0.9641  Center@1=0.0694  MedErr=216.21px
#   [rural3] HNSW:       R@1=0.5315  R@5=0.7552  R@10=0.8415  R@20=0.9184  Center@1=0.0769  MedErr=389.68px  (n=429)
#   [rural3] HNSW+HMM:   R@1=0.8462  R@5=0.9650  R@10=0.9720  R@20=0.9814  Center@1=0.1399  MedErr=214.15px
#   [school] HNSW:       R@1=0.9062  R@5=0.9681  R@10=0.9812  R@20=0.9925  Center@1=0.3396  MedErr=118.59px  (n=533)
#   [school] HNSW+HMM:   R@1=0.9981  R@5=1.0000  R@10=1.0000  R@20=1.0000  Center@1=0.3809  MedErr=105.09px
#   [suburbs1] HNSW:       R@1=0.5771  R@5=0.8282  R@10=0.9207  R@20=0.9648  Center@1=0.0396  MedErr=350.94px  (n=227)
#   [suburbs1] HNSW+HMM:   R@1=0.9163  R@5=0.9824  R@10=0.9912  R@20=0.9956  Center@1=0.1189  MedErr=247.85px
#   [suburbs2] HNSW:       R@1=0.7131  R@5=0.9652  R@10=0.9959  R@20=1.0000  Center@1=0.1148  MedErr=258.00px  (n=488)
#   [suburbs2] HNSW+HMM:   R@1=0.9734  R@5=0.9980  R@10=1.0000  R@20=1.0000  Center@1=0.1783  MedErr=159.03px
#   [village1] HNSW:       R@1=0.8806  R@5=0.9903  R@10=1.0000  R@20=1.0000  Center@1=0.1968  MedErr=188.94px  (n=310)
#   [village1] HNSW+HMM:   R@1=0.9645  R@5=0.9968  R@10=1.0000  R@20=1.0000  Center@1=0.2613  MedErr=164.41px
#   [village2] HNSW:       R@1=0.6594  R@5=0.8872  R@10=0.9458  R@20=0.9935  Center@1=0.0694  MedErr=315.82px  (n=461)
#   [village2] HNSW+HMM:   R@1=0.9458  R@5=0.9870  R@10=0.9978  R@20=1.0000  Center@1=0.1388  MedErr=180.40px
# 按场景检索 Top-10 已保存: /home/lty/code_my/ch3/results/hnsw_top10.txt, /home/lty/code_my/ch3/results/hnsw_hmm_top10.txt
# GT 已保存: /home/lty/code_my/ch3/results/gt_25.txt
